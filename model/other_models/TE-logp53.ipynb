# %%
import torch
from datetime import datetime
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
import torch
import numpy as np
from rdkit.Chem import AllChem
from rdkit import Chem
from collections import defaultdict
import os,time
from torch_geometric.data import Data
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score

# %%
def load_data_long(dataset, device):
    mole_dict = {1: "H", 2: "He", 3: "Li", 4: "Be", 5: "B", 6: "C", 7: "N", 8: "O", 9: "F", 10: " Ne",
                11: "Na", 12:"Mg", 13: "Al", 14:"Si", 15:"P", 16: "S", 17: "Cl", 18:"Ar", 19:"K", 20:"Ca", 22:"Ti", 24:"Cr", 26:"Fe", 28:"Ni",
                29:"Cu", 31:"Ga", 32:"Ge", 34:"Se", 35:"Br", 40:"Zr", 44:"Ru", 45:"Rh", 46:"Pd", 47:"Ag", 50:"Sn", 51:"Sb", 52:"Te", 53: "I", 65:"Tb", 75:"Re", 77:"Ir", 78:"Pt", 79:"Au", 80:"Hg",
                81:"Tl", 82:"Pb", 83:"Bi"}

    pair_list = ["Br", "Cl", "Si", "Na", "Ca", "Ge", "Cu", "Au", "Sn", "Tb", "Pt", "Re", "Ru", "Bi", "Li", "Fe", "Sb", "Hg","Pb", "Se", "Ag","Cr","Pd","Ga","Mg","Ni","Ir","Rh","Te","Ti","Al","Zr","Tl"]

    data_file = f"./original_datasets/{dataset}/{dataset}_train"
    file = open(data_file, "r")
    node_types = set()
    label_types = set()
    tr_len = 0
    for line in file:
        tr_len += 1
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        i = 0
        s = []
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                s.append(smiles[i] + smiles[i+1])
                i += 2
            else:
                s.append(smiles[i].upper())
                i += 1
        node_types |= set(s)
        label_types.add(label)
    file.close()

    te_len = 0
    data_file = f"./original_datasets/{dataset}/{dataset}_test"
    file = open(data_file, "r")
    for line in file:
        te_len += 1
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        i = 0
        s = []
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                s.append(smiles[i] + smiles[i+1])
                i += 2
            else:
                s.append(smiles[i].upper())
                i += 1
        node_types |= set(s)
        label_types.add(label)
    file.close()

    #print(tr_len)
    #print(te_len)

    node2index = {n: i for i, n in enumerate(node_types)}
    label2index = {l: i for i, l in enumerate(label_types)}

    #print(node2index)
    #print(label2index)

    data_file = f"./original_datasets/{dataset}/{dataset}_train"
    file = open(data_file, "r")
    train_adjlists = []
    train_features = []
    train_sequence = []
    train_labels = torch.zeros(tr_len)
    for line in file:
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        mol = AllChem.MolFromSmiles(smiles)
        graph_nodes = []
        for atom in mol.GetAtoms():
            graph_nodes.append(mole_dict[atom.GetAtomicNum()])
        # print(graph_nodes)
        i = 0
        s = 0
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                i += 2
            else:
                i += 1
            s += 1

        feature = torch.zeros(s, len(node_types))

        map = {}
        se_num = 0
        gr_num = 0
        i = 0
        smiles_seq = []
        while i < len(smiles):
            this_str = smiles[i]
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                this_str = smiles[i] + smiles[i+1]
                i += 2
            else:
                this_str = this_str.upper()
                i += 1
            smiles_seq.append(node2index[this_str])
            if this_str in graph_nodes and this_str == mole_dict[mol.GetAtoms()[gr_num].GetAtomicNum()]:
                map[gr_num] = se_num
                gr_num += 1
            feature[se_num, node2index[this_str]] = 1
            se_num += 1

        adj_list = defaultdict(list)
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            # print(i,j)
            typ = bond.GetBondType()
            adj_list[map[i]].append(map[j])
            adj_list[map[j]].append(map[i])
            if typ == Chem.rdchem.BondType.DOUBLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
            elif typ == Chem.rdchem.BondType.TRIPLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])

        # train_labels[len(train_adjlists)]= int(label2index[label])
        train_labels[len(train_adjlists)]= int(label)
        train_adjlists.append(adj_list)
        train_features.append(torch.FloatTensor(feature).to(device))
        train_sequence.append(torch.tensor(smiles_seq))
    file.close()

    data_file = f"./original_datasets/{dataset}/{dataset}_test"
    file = open(data_file, "r")
    test_adjlists = []
    test_features = []
    test_sequence = []
    test_labels = np.zeros(te_len)
    for line in file:
        smiles = line.split("\t")[1]
        # print(smiles)
        label = line.split("\t")[2][:-1]
        mol = AllChem.MolFromSmiles(smiles)
        graph_nodes = []
        for atom in mol.GetAtoms():
            graph_nodes.append(mole_dict[atom.GetAtomicNum()])
        # print(graph_nodes)
        i = 0
        s = 0
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                i += 2
            else:
                i += 1
            s += 1

        feature = torch.zeros(s, len(node_types))

        map = {}
        se_num = 0
        gr_num = 0
        i = 0
        smiles_seq = []
        while i < len(smiles):
            this_str = smiles[i]
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                this_str = smiles[i] + smiles[i+1]
                i += 2
            else:
                this_str = this_str.upper()
                i += 1
            smiles_seq.append(node2index[this_str])
            if this_str in graph_nodes and this_str == mole_dict[mol.GetAtoms()[gr_num].GetAtomicNum()]:
                map[gr_num] = se_num
                gr_num += 1
            feature[se_num, node2index[this_str]] = 1
            se_num += 1

        adj_list = defaultdict(list)
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            # print(i,j)
            typ = bond.GetBondType()
            adj_list[map[i]].append(map[j])
            adj_list[map[j]].append(map[i])
            if typ == Chem.rdchem.BondType.DOUBLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
            elif typ == Chem.rdchem.BondType.TRIPLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])

        # test_labels[len(test_adjlists)] = int(label2index[label])
        test_labels[len(test_adjlists)] = int(label)
        test_adjlists.append(adj_list)
        test_features.append(torch.FloatTensor(feature).to(device))
        test_sequence.append(torch.tensor(smiles_seq))
    file.close()

    train_data = {}
    train_data['adj_lists'] = train_adjlists
    train_data['features'] = train_features
     # Pad train_sequence to length 100
    padded_train_sequence = []
    for seq in train_sequence:
      padded_seq = torch.nn.functional.pad(seq, (0, 100 - len(seq)), 'constant', 0)
      padded_train_sequence.append(padded_seq)
      train_data['sequence'] = padded_train_sequence

    test_data = {}
    test_data['adj_lists'] = test_adjlists
    test_data['features'] = test_features
    padded_test_sequence = []
    for seq in test_sequence:
      padded_seq = torch.nn.functional.pad(seq, (0, 100 - len(seq)), 'constant', 0)
      padded_test_sequence.append(padded_seq)
      test_data['sequence'] = padded_test_sequence

    return train_data, train_labels, test_data, test_labels


class CustomDataset(Dataset):
    def __init__(self, data_list, sequence_list):
        self.data_list = data_list
        self.sequence_list = sequence_list

    def __getitem__(self, index):
        data = self.data_list[index]
        sequence = self.sequence_list[index]
        return data, sequence

    def __len__(self):
        return len(self.data_list)
    

def adj_list_to_adj_matrix(adj_list):
    num_nodes = max(adj_list.keys()) + 1
    adj_matrix = torch.zeros((num_nodes, num_nodes), dtype=torch.float)
    for node, neighbors in adj_list.items():
        for neighbor in neighbors:
            adj_matrix[node][neighbor] = 1.0
            adj_matrix[neighbor][node] = 1.0
    return adj_matrix

# %%
train_data, train_labels, test_data, test_labels=load_data_long("logp", device="cuda:0" if torch.cuda.is_available() else "cpu")
device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
input_dim_train = train_data['features'][0].size(-1)
input_dim_test = test_data['features'][0].size(-1)


adj_matrices_train = [adj_list_to_adj_matrix(adj_list) for adj_list in train_data['adj_lists']]
adj_matrices_test = [adj_list_to_adj_matrix(adj_list) for adj_list in test_data['adj_lists']]



data_list_train = [Data(x=torch.tensor(features, dtype=torch.float),
                              edge_index=torch.nonzero(adj_matrix, as_tuple=False).t().contiguous(),
                              y=torch.tensor(label, dtype=torch.float))
                         for features, adj_matrix, label in zip(train_data['features'], adj_matrices_train, train_labels)]
data_list_test = [Data(x=torch.tensor(features, dtype=torch.float),
                                edge_index=torch.nonzero(adj_matrix, as_tuple=False).t().contiguous(),
                                y=torch.tensor(label, dtype=torch.float))
                            for features, adj_matrix, label in zip(test_data['features'], adj_matrices_test, test_labels)]

train_dataset = CustomDataset(data_list_train, train_data['sequence'])
test_dataset = CustomDataset(data_list_test, test_data['sequence'])
# Out:
# C:\Users\vysha\AppData\Local\Temp\ipykernel_138888\2688029661.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_list_train = [Data(x=torch.tensor(features, dtype=torch.float),
# C:\Users\vysha\AppData\Local\Temp\ipykernel_138888\2688029661.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y=torch.tensor(label, dtype=torch.float))
# C:\Users\vysha\AppData\Local\Temp\ipykernel_138888\2688029661.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_list_test = [Data(x=torch.tensor(features, dtype=torch.float),

# %%
import torch
import torch.nn as nn

class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length=100):
        super(TransformerModel, self).__init__()
        self.device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.transformer_encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward), num_layers=num_encoder_layers)
        self.fc = nn.Linear(d_model, 1)

    def forward(self, x):
        x = self.embedding(x).to(self.device)
        x = torch.transpose(x, 0, 1).to(self.device)
        x = self.transformer_encoder(x).to(self.device)
        x = torch.mean(x, dim=0).to(self.device)
        x = self.fc(x).to(self.device)
        x = x.mean(dim=0, keepdim=True).to(self.device)
        return x

# Define hyperparameters
vocab_size = 100
d_model = 100
nhead = 5
num_encoder_layers = 3
dim_feedforward = 512
max_length = 100
batch_size = 1
num_epochs = 100

# Initialize model, loss, and optimizer
model = TransformerModel(vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
# Out:
# c:\Python312\Lib\site-packages\torch\nn\modules\transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# 4 HEADS 3 LAYERS

# %%
import torch.nn as nn
current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime('%Y-%m-%d_%H-%M-%S')
data_name = "logp"  # Replace with the actual data name
type = "TE"  # Replace with the actual type

session_name = f'{data_name}_{formatted_datetime}/{type}'
folder_path = os.path.join('saved_models', session_name)
os.makedirs(folder_path, exist_ok=True)

output_dir_train = f'output/{data_name}/train/{type}'
os.makedirs(output_dir_train, exist_ok=True)
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name_train = f'{output_dir_train}/train_accuracy_details_{current_time}.txt'

output_dir_test = f'output/{data_name}/test'
os.makedirs(output_dir_test, exist_ok=True)
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name_test = f'{output_dir_test}/test_accuracy_details_{current_time}.txt'

best_train_accuracy = 0.0
best_test_accuracy = 0.0

# Training loop
reconstruction_weight = 0.1  # Weight for the reconstruction loss
with open(file_name_train, 'a') as file_train, open(file_name_test, 'a') as file_test:
    for epoch in range(100):
        total_correct = 0
        total_samples = 0
        true_labels_train = []
        pred_probs_train = []
        losses = 0.0

        for data_batch in train_dataset:
            graph_data_batch = data_batch[0]
            sequence_inputs = data_batch[1].to(device)
            sequence_targets = graph_data_batch.y

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            output= model(sequence_inputs)

            # Compute binary predictions
            binary_predictions = (output >= 0.5).float()

            # Compute batch accuracy
            batch_correct = (binary_predictions == sequence_targets).sum().item()
            total_correct += batch_correct
            total_samples += 1

            output = output.to(device)
            sequence_targets = sequence_targets.to(device)

            true_labels_train.append(sequence_targets.cpu().numpy().reshape(-1))
            pred_probs_train.append(output.detach().cpu().numpy())

            # Cast sequence_inputs to float
            sequence_inputs = sequence_inputs.float()


            # Compute loss
            loss = criterion(output, sequence_targets.view(-1))
            losses += loss.item()

            # Backward pass
            loss.backward()

            # Update weights
            optimizer.step()

        # Compute epoch accuracy
        epoch_train_accuracy = (total_correct / total_samples) * 100
        print(f"Epoch {epoch + 1}/{100}, Epoch Accuracy: {epoch_train_accuracy:.4f}")

        if epoch_train_accuracy >= best_train_accuracy:
            best_train_accuracy = epoch_train_accuracy
            model_path = os.path.join(folder_path, f'train_best_model_{best_train_accuracy:.3f}.pth')
            torch.save(model.state_dict(), model_path)
            print("Saved model with accuracy train model with accuracy{:.2f}% to {}".format(best_train_accuracy,
                                                                                             model_path))

        true_labels_train = np.concatenate(true_labels_train)
        pred_probs_train = np.concatenate(pred_probs_train)

        precision_train = precision_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        recall_train = recall_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        auc_roc_train = roc_auc_score(true_labels_train, pred_probs_train)
        f1_train = f1_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        print(
            f"Train AUC-ROC: {auc_roc_train:.4f}, Train F1 Score: {f1_train:.4f} , Train Precision: {precision_train:.4f}, Train Recall: {recall_train:.4f}\n")
        file_train.write(
            f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {losses:.4f}, Train Accuracy: {epoch_train_accuracy:.4f}, Train AUC-ROC: {auc_roc_train:.4f}, Train F1 Score: {f1_train:.4f} , Train Precision: {precision_train:.4f}, Train Recall: {recall_train:.4f}\n')

        total_correct = 0
        total_samples = 0
        true_labels_test = []
        pred_probs_test = []

        for data_batch in test_dataset:
            graph_data_batch = data_batch[0]
            sequence_inputs = data_batch[1].to(device)                                                      
            sequence_targets = graph_data_batch.y

            output= model(sequence_inputs)
            binary_predictions = (output >= 0.5).float()

            batch_correct = (binary_predictions == sequence_targets).sum().item()
            total_correct += batch_correct
            total_samples += 1

            true_labels_test.append(sequence_targets.cpu().numpy().reshape(-1))
            pred_probs_test.append(output.detach().cpu().numpy())

        epoch_test_accuracy = (total_correct / total_samples) * 100
        print(f"Epoch Testing Accuracy : {epoch_test_accuracy:.4f}")

        if epoch_test_accuracy >= best_test_accuracy:
            best_test_accuracy = epoch_test_accuracy
            model_path = os.path.join(folder_path, f'test_best_model_{best_test_accuracy:.3f}.pth')
            torch.save(model.state_dict(), model_path)
            print("Saved model with Test Model with accuracy {:.2f}% to {}".format(best_test_accuracy, model_path))

        true_labels_test = np.concatenate(true_labels_test)
        pred_probs_test = np.concatenate(pred_probs_test)
        #pred_probs_test.append(output.detach().cpu().numpy().reshape(-1))
        
        #print(true_labels_test, pred_probs_test)
        precision_test = precision_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        recall_test = recall_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        auc_roc_test = roc_auc_score(true_labels_test, pred_probs_test)
        f1_test = f1_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        print(
            f"Test AUC-ROC: {auc_roc_test:.4f}, Test F1 Score: {f1_test:.4f}, Test Precision: {precision_test:.4f}, Test Recall: {recall_test:.4f}\n")
        file_test.write(
            f'Epoch {epoch + 1}/{num_epochs}, Test Accuracy: {epoch_test_accuracy:.4f},Test AUC-ROC: {auc_roc_test:.4f}, Test F1 Score: {f1_test:.4f}, Test Precision: {precision_test:.4f}, Test Recall: {recall_test:.4f} \n')
file_test.close()
file_train.close()
# Out:
# c:\Python312\Lib\site-packages\torch\nn\functional.py:5476: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Epoch 1/100, Epoch Accuracy: 69.1625
# Saved model with accuracy train model with accuracy69.16% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_69.163.pth
# Train AUC-ROC: 0.7787, Train F1 Score: 0.6326 , Train Precision: 0.7858, Train Recall: 0.5294
#
# Epoch Testing Accuracy : 84.4000
# Saved model with Test Model with accuracy 84.40% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_84.400.pth
# Test AUC-ROC: 0.9232, Test F1 Score: 0.8415, Test Precision: 0.8398, Test Recall: 0.8432
#
# Epoch 2/100, Epoch Accuracy: 82.7125
# Saved model with accuracy train model with accuracy82.71% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_82.713.pth
# Train AUC-ROC: 0.9064, Train F1 Score: 0.8127 , Train Precision: 0.8897, Train Recall: 0.7480
#
# Epoch Testing Accuracy : 84.1000
# Test AUC-ROC: 0.9378, Test F1 Score: 0.8136, Test Precision: 0.9586, Test Recall: 0.7067
#
# Epoch 3/100, Epoch Accuracy: 84.6750
# Saved model with accuracy train model with accuracy84.67% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_84.675.pth
# Train AUC-ROC: 0.9261, Train F1 Score: 0.8348 , Train Precision: 0.9087, Train Recall: 0.7719
#
# Epoch Testing Accuracy : 82.5000
# Test AUC-ROC: 0.9378, Test F1 Score: 0.7904, Test Precision: 0.9593, Test Recall: 0.6721
#
# Epoch 4/100, Epoch Accuracy: 86.1375
# Saved model with accuracy train model with accuracy86.14% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_86.138.pth
# Train AUC-ROC: 0.9407, Train F1 Score: 0.8527 , Train Precision: 0.9129, Train Recall: 0.7999
#
# Epoch Testing Accuracy : 85.6000
# Saved model with Test Model with accuracy 85.60% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_85.600.pth
# Test AUC-ROC: 0.9511, Test F1 Score: 0.8318, Test Precision: 0.9753, Test Recall: 0.7251
#
# Epoch 5/100, Epoch Accuracy: 87.6875
# Saved model with accuracy train model with accuracy87.69% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_87.688.pth
# Train AUC-ROC: 0.9473, Train F1 Score: 0.8690 , Train Precision: 0.9313, Train Recall: 0.8146
#
# Epoch Testing Accuracy : 85.6000
# Saved model with Test Model with accuracy 85.60% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_85.600.pth
# Test AUC-ROC: 0.9588, Test F1 Score: 0.8302, Test Precision: 0.9860, Test Recall: 0.7169
#
# Epoch 6/100, Epoch Accuracy: 88.2500
# Saved model with accuracy train model with accuracy88.25% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_88.250.pth
# Train AUC-ROC: 0.9557, Train F1 Score: 0.8742 , Train Precision: 0.9437, Train Recall: 0.8143
#
# Epoch Testing Accuracy : 84.0000
# Test AUC-ROC: 0.9559, Test F1 Score: 0.8072, Test Precision: 0.9882, Test Recall: 0.6823
#
# Epoch 7/100, Epoch Accuracy: 88.1500
# Train AUC-ROC: 0.9508, Train F1 Score: 0.8746 , Train Precision: 0.9318, Train Recall: 0.8240
#
# Epoch Testing Accuracy : 86.7000
# Saved model with Test Model with accuracy 86.70% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_86.700.pth
# Test AUC-ROC: 0.9527, Test F1 Score: 0.8452, Test Precision: 0.9864, Test Recall: 0.7393
#
# Epoch 8/100, Epoch Accuracy: 89.0000
# Saved model with accuracy train model with accuracy89.00% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_89.000.pth
# Train AUC-ROC: 0.9579, Train F1 Score: 0.8843 , Train Precision: 0.9355, Train Recall: 0.8385
#
# Epoch Testing Accuracy : 88.7000
# Saved model with Test Model with accuracy 88.70% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_88.700.pth
# Test AUC-ROC: 0.9514, Test F1 Score: 0.8762, Test Precision: 0.9479, Test Recall: 0.8147
#
# Epoch 9/100, Epoch Accuracy: 88.6000
# Train AUC-ROC: 0.9550, Train F1 Score: 0.8788 , Train Precision: 0.9416, Train Recall: 0.8238
#
# Epoch Testing Accuracy : 88.1000
# Test AUC-ROC: 0.9562, Test F1 Score: 0.8649, Test Precision: 0.9769, Test Recall: 0.7760
#
# Epoch 10/100, Epoch Accuracy: 87.5125
# Train AUC-ROC: 0.9506, Train F1 Score: 0.8651 , Train Precision: 0.9437, Train Recall: 0.7986
#
# Epoch Testing Accuracy : 81.9000
# Test AUC-ROC: 0.9393, Test F1 Score: 0.7768, Test Precision: 0.9844, Test Recall: 0.6415
#
# Epoch 11/100, Epoch Accuracy: 86.9000
# Train AUC-ROC: 0.9436, Train F1 Score: 0.8607 , Train Precision: 0.9222, Train Recall: 0.8068
#
# Epoch Testing Accuracy : 79.1000
# Test AUC-ROC: 0.9587, Test F1 Score: 0.7317, Test Precision: 0.9896, Test Recall: 0.5804
#
# Epoch 12/100, Epoch Accuracy: 87.2500
# Train AUC-ROC: 0.9496, Train F1 Score: 0.8640 , Train Precision: 0.9289, Train Recall: 0.8076
#
# Epoch Testing Accuracy : 85.1000
# Test AUC-ROC: 0.9488, Test F1 Score: 0.8261, Test Precision: 0.9672, Test Recall: 0.7210
#
# Epoch 13/100, Epoch Accuracy: 87.4375
# Train AUC-ROC: 0.9471, Train F1 Score: 0.8664 , Train Precision: 0.9282, Train Recall: 0.8123
#
# Epoch Testing Accuracy : 83.1000
# Test AUC-ROC: 0.9404, Test F1 Score: 0.7971, Test Precision: 0.9708, Test Recall: 0.6762
#
# Epoch 14/100, Epoch Accuracy: 85.0875
# Train AUC-ROC: 0.9326, Train F1 Score: 0.8383 , Train Precision: 0.9186, Train Recall: 0.7709
#
# Epoch Testing Accuracy : 83.9000
# Test AUC-ROC: 0.9397, Test F1 Score: 0.8058, Test Precision: 0.9882, Test Recall: 0.6802
#
# Epoch 15/100, Epoch Accuracy: 85.6750
# Train AUC-ROC: 0.9374, Train F1 Score: 0.8458 , Train Precision: 0.9190, Train Recall: 0.7834
#
# Epoch Testing Accuracy : 81.9000
# Test AUC-ROC: 0.9386, Test F1 Score: 0.7779, Test Precision: 0.9784, Test Recall: 0.6456
#
# Epoch 16/100, Epoch Accuracy: 85.5125
# Train AUC-ROC: 0.9366, Train F1 Score: 0.8428 , Train Precision: 0.9244, Train Recall: 0.7744
#
# Epoch Testing Accuracy : 79.3000
# Test AUC-ROC: 0.9333, Test F1 Score: 0.7336, Test Precision: 0.9965, Test Recall: 0.5804
#
# Epoch 17/100, Epoch Accuracy: 85.2750
# Train AUC-ROC: 0.9303, Train F1 Score: 0.8390 , Train Precision: 0.9289, Train Recall: 0.7650
#
# Epoch Testing Accuracy : 82.9000
# Test AUC-ROC: 0.9403, Test F1 Score: 0.7927, Test Precision: 0.9790, Test Recall: 0.6660
#
# Epoch 18/100, Epoch Accuracy: 83.8250
# Train AUC-ROC: 0.9207, Train F1 Score: 0.8206 , Train Precision: 0.9244, Train Recall: 0.7378
#
# Epoch Testing Accuracy : 85.5000
# Test AUC-ROC: 0.9315, Test F1 Score: 0.8373, Test Precision: 0.9325, Test Recall: 0.7597
#
# Epoch 19/100, Epoch Accuracy: 82.3125
# Train AUC-ROC: 0.9069, Train F1 Score: 0.8020 , Train Precision: 0.9142, Train Recall: 0.7144
#
# Epoch Testing Accuracy : 72.3000
# Test AUC-ROC: 0.7953, Test F1 Score: 0.6321, Test Precision: 0.9084, Test Recall: 0.4847
#
# Epoch 20/100, Epoch Accuracy: 81.2625
# Train AUC-ROC: 0.8927, Train F1 Score: 0.7929 , Train Precision: 0.8896, Train Recall: 0.7151
#
# Epoch Testing Accuracy : 76.2000
# Test AUC-ROC: 0.8874, Test F1 Score: 0.7083, Test Precision: 0.8892, Test Recall: 0.5886
#
# Epoch 21/100, Epoch Accuracy: 69.8500
# Train AUC-ROC: 0.8011, Train F1 Score: 0.6405 , Train Precision: 0.7965, Train Recall: 0.5356
#
# Epoch Testing Accuracy : 70.6000
# Test AUC-ROC: 0.7437, Test F1 Score: 0.7443, Test Precision: 0.6495, Test Recall: 0.8717
#
# Epoch 22/100, Epoch Accuracy: 72.8375
# Train AUC-ROC: 0.8274, Train F1 Score: 0.6830 , Train Precision: 0.8234, Train Recall: 0.5835
#
# Epoch Testing Accuracy : 74.5000
# Test AUC-ROC: 0.9081, Test F1 Score: 0.6605, Test Precision: 0.9538, Test Recall: 0.5051
#
# Epoch 23/100, Epoch Accuracy: 78.5625
# Train AUC-ROC: 0.8691, Train F1 Score: 0.7561 , Train Precision: 0.8804, Train Recall: 0.6625
#
# Epoch Testing Accuracy : 74.9000
# Test AUC-ROC: 0.8864, Test F1 Score: 0.6631, Test Precision: 0.9724, Test Recall: 0.5031
#
# Epoch 24/100, Epoch Accuracy: 50.6375
# Train AUC-ROC: 0.5301, Train F1 Score: 0.1346 , Train Precision: 0.5572, Train Recall: 0.0765
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.4771, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 25/100, Epoch Accuracy: 49.8375
# Train AUC-ROC: 0.5106, Train F1 Score: 0.0286 , Train Precision: 0.4958, Train Recall: 0.0147
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.5112, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 26/100, Epoch Accuracy: 49.8125
# Train AUC-ROC: 0.5047, Train F1 Score: 0.0089 , Train Precision: 0.4615, Train Recall: 0.0045
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.5244, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 27/100, Epoch Accuracy: 50.0750
# Train AUC-ROC: 0.5120, Train F1 Score: 0.0182 , Train Precision: 0.6607, Train Recall: 0.0092
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.5449, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 28/100, Epoch Accuracy: 60.8500
# Train AUC-ROC: 0.6866, Train F1 Score: 0.4474 , Train Precision: 0.7657, Train Recall: 0.3161
#
# Epoch Testing Accuracy : 78.4000
# Test AUC-ROC: 0.8521, Test F1 Score: 0.7523, Test Precision: 0.8609, Test Recall: 0.6680
#
# Epoch 29/100, Epoch Accuracy: 77.5250
# Train AUC-ROC: 0.8222, Train F1 Score: 0.7594 , Train Precision: 0.8198, Train Recall: 0.7074
#
# Epoch Testing Accuracy : 79.1000
# Test AUC-ROC: 0.8838, Test F1 Score: 0.7391, Test Precision: 0.9548, Test Recall: 0.6029
#
# Epoch 30/100, Epoch Accuracy: 82.1375
# Train AUC-ROC: 0.8716, Train F1 Score: 0.8068 , Train Precision: 0.8815, Train Recall: 0.7438
#
# Epoch Testing Accuracy : 85.3000
# Test AUC-ROC: 0.9317, Test F1 Score: 0.8308, Test Precision: 0.9550, Test Recall: 0.7352
#
# Epoch 31/100, Epoch Accuracy: 86.0250
# Train AUC-ROC: 0.9159, Train F1 Score: 0.8500 , Train Precision: 0.9206, Train Recall: 0.7894
#
# Epoch Testing Accuracy : 81.9000
# Test AUC-ROC: 0.9443, Test F1 Score: 0.7746, Test Precision: 0.9968, Test Recall: 0.6334
#
# Epoch 32/100, Epoch Accuracy: 88.7375
# Train AUC-ROC: 0.9491, Train F1 Score: 0.8812 , Train Precision: 0.9356, Train Recall: 0.8328
#
# Epoch Testing Accuracy : 86.5000
# Test AUC-ROC: 0.9653, Test F1 Score: 0.8421, Test Precision: 0.9890, Test Recall: 0.7332
#
# Epoch 33/100, Epoch Accuracy: 88.5625
# Train AUC-ROC: 0.9527, Train F1 Score: 0.8788 , Train Precision: 0.9378, Train Recall: 0.8268
#
# Epoch Testing Accuracy : 79.4000
# Test AUC-ROC: 0.9493, Test F1 Score: 0.7345, Test Precision: 1.0000, Test Recall: 0.5804
#
# Epoch 34/100, Epoch Accuracy: 87.7750
# Train AUC-ROC: 0.9487, Train F1 Score: 0.8690 , Train Precision: 0.9389, Train Recall: 0.8088
#
# Epoch Testing Accuracy : 87.4000
# Test AUC-ROC: 0.9629, Test F1 Score: 0.8548, Test Precision: 0.9841, Test Recall: 0.7556
#
# Epoch 35/100, Epoch Accuracy: 83.8250
# Train AUC-ROC: 0.9287, Train F1 Score: 0.8183 , Train Precision: 0.9373, Train Recall: 0.7261
#
# Epoch Testing Accuracy : 86.1000
# Test AUC-ROC: 0.9615, Test F1 Score: 0.8393, Test Precision: 0.9706, Test Recall: 0.7393
#
# Epoch 36/100, Epoch Accuracy: 79.6375
# Train AUC-ROC: 0.8883, Train F1 Score: 0.7631 , Train Precision: 0.9159, Train Recall: 0.6540
#
# Epoch Testing Accuracy : 86.0000
# Test AUC-ROC: 0.9645, Test F1 Score: 0.8357, Test Precision: 0.9861, Test Recall: 0.7251
#
# Epoch 37/100, Epoch Accuracy: 83.9250
# Train AUC-ROC: 0.9190, Train F1 Score: 0.8265 , Train Precision: 0.9011, Train Recall: 0.7632
#
# Epoch Testing Accuracy : 81.9000
# Test AUC-ROC: 0.9413, Test F1 Score: 0.7785, Test Precision: 0.9755, Test Recall: 0.6477
#
# Epoch 38/100, Epoch Accuracy: 81.5125
# Train AUC-ROC: 0.9038, Train F1 Score: 0.7885 , Train Precision: 0.9249, Train Recall: 0.6872
#
# Epoch Testing Accuracy : 53.0000
# Test AUC-ROC: 0.5459, Test F1 Score: 0.0820, Test Precision: 1.0000, Test Recall: 0.0428
#
# Epoch 39/100, Epoch Accuracy: 67.9625
# Train AUC-ROC: 0.7817, Train F1 Score: 0.5764 , Train Precision: 0.8553, Train Recall: 0.4347
#
# Epoch Testing Accuracy : 83.7000
# Test AUC-ROC: 0.9375, Test F1 Score: 0.8146, Test Precision: 0.9227, Test Recall: 0.7291
#
# Epoch 40/100, Epoch Accuracy: 83.4125
# Train AUC-ROC: 0.9119, Train F1 Score: 0.8183 , Train Precision: 0.9079, Train Recall: 0.7448
#
# Epoch Testing Accuracy : 84.5000
# Test AUC-ROC: 0.9313, Test F1 Score: 0.8260, Test Precision: 0.9200, Test Recall: 0.7495
#
# Epoch 41/100, Epoch Accuracy: 81.2625
# Train AUC-ROC: 0.8851, Train F1 Score: 0.8007 , Train Precision: 0.8581, Train Recall: 0.7505
#
# Epoch Testing Accuracy : 82.5000
# Test AUC-ROC: 0.9119, Test F1 Score: 0.8289, Test Precision: 0.7970, Test Recall: 0.8635
#
# Epoch 42/100, Epoch Accuracy: 80.9625
# Train AUC-ROC: 0.8727, Train F1 Score: 0.8113 , Train Precision: 0.8066, Train Recall: 0.8161
#
# Epoch Testing Accuracy : 86.4000
# Test AUC-ROC: 0.9358, Test F1 Score: 0.8499, Test Precision: 0.9277, Test Recall: 0.7841
#
# Epoch 43/100, Epoch Accuracy: 78.3625
# Train AUC-ROC: 0.8646, Train F1 Score: 0.7679 , Train Precision: 0.8309, Train Recall: 0.7139
#
# Epoch Testing Accuracy : 81.8000
# Test AUC-ROC: 0.9204, Test F1 Score: 0.7838, Test Precision: 0.9402, Test Recall: 0.6721
#
# Epoch 44/100, Epoch Accuracy: 77.0750
# Train AUC-ROC: 0.8646, Train F1 Score: 0.7176 , Train Precision: 0.9388, Train Recall: 0.5808
#
# Epoch Testing Accuracy : 76.0000
# Test AUC-ROC: 0.8961, Test F1 Score: 0.6842, Test Precision: 0.9665, Test Recall: 0.5295
#
# Epoch 45/100, Epoch Accuracy: 71.6125
# Train AUC-ROC: 0.8026, Train F1 Score: 0.6267 , Train Precision: 0.9203, Train Recall: 0.4751
#
# Epoch Testing Accuracy : 76.7000
# Test AUC-ROC: 0.8390, Test F1 Score: 0.7876, Test Precision: 0.7129, Test Recall: 0.8798
#
# Epoch 46/100, Epoch Accuracy: 75.1500
# Train AUC-ROC: 0.8285, Train F1 Score: 0.7073 , Train Precision: 0.8640, Train Recall: 0.5987
#
# Epoch Testing Accuracy : 51.7000
# Test AUC-ROC: 0.6946, Test F1 Score: 0.0658, Test Precision: 0.6538, Test Recall: 0.0346
#
# Epoch 47/100, Epoch Accuracy: 60.1625
# Train AUC-ROC: 0.7080, Train F1 Score: 0.4795 , Train Precision: 0.6954, Train Recall: 0.3659
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.4873, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 48/100, Epoch Accuracy: 57.5000
# Train AUC-ROC: 0.6501, Train F1 Score: 0.3543 , Train Precision: 0.7440, Train Recall: 0.2326
#
# Epoch Testing Accuracy : 77.9000
# Test AUC-ROC: 0.8416, Test F1 Score: 0.7520, Test Precision: 0.8375, Test Recall: 0.6823
#
# Epoch 49/100, Epoch Accuracy: 68.0875
# Train AUC-ROC: 0.7651, Train F1 Score: 0.6384 , Train Precision: 0.7393, Train Recall: 0.5618
#
# Epoch Testing Accuracy : 69.6000
# Test AUC-ROC: 0.7610, Test F1 Score: 0.7008, Test Precision: 0.6781, Test Recall: 0.7251
#
# Epoch 50/100, Epoch Accuracy: 66.0375
# Train AUC-ROC: 0.7722, Train F1 Score: 0.5510 , Train Precision: 0.8176, Train Recall: 0.4155
#
# Epoch Testing Accuracy : 79.0000
# Test AUC-ROC: 0.8606, Test F1 Score: 0.7529, Test Precision: 0.8914, Test Recall: 0.6517
#
# Epoch 51/100, Epoch Accuracy: 56.7875
# Train AUC-ROC: 0.6822, Train F1 Score: 0.3441 , Train Precision: 0.7204, Train Recall: 0.2261
#
# Epoch Testing Accuracy : 64.6000
# Test AUC-ROC: 0.8447, Test F1 Score: 0.4732, Test Precision: 0.8785, Test Recall: 0.3238
#
# Epoch 52/100, Epoch Accuracy: 75.8875
# Train AUC-ROC: 0.8421, Train F1 Score: 0.7205 , Train Precision: 0.8605, Train Recall: 0.6196
#
# Epoch Testing Accuracy : 73.8000
# Test AUC-ROC: 0.8967, Test F1 Score: 0.6516, Test Precision: 0.9387, Test Recall: 0.4990
#
# Epoch 53/100, Epoch Accuracy: 76.6750
# Train AUC-ROC: 0.8496, Train F1 Score: 0.7258 , Train Precision: 0.8840, Train Recall: 0.6157
#
# Epoch Testing Accuracy : 82.1000
# Test AUC-ROC: 0.9066, Test F1 Score: 0.8081, Test Precision: 0.8529, Test Recall: 0.7678
#
# Epoch 54/100, Epoch Accuracy: 64.1500
# Train AUC-ROC: 0.7365, Train F1 Score: 0.4860 , Train Precision: 0.8648, Train Recall: 0.3380
#
# Epoch Testing Accuracy : 51.1000
# Test AUC-ROC: 0.4940, Test F1 Score: 0.0081, Test Precision: 1.0000, Test Recall: 0.0041
#
# Epoch 55/100, Epoch Accuracy: 52.4125
# Train AUC-ROC: 0.5584, Train F1 Score: 0.1431 , Train Precision: 0.7378, Train Recall: 0.0793
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.5737, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 56/100, Epoch Accuracy: 57.5625
# Train AUC-ROC: 0.6777, Train F1 Score: 0.3902 , Train Precision: 0.6984, Train Recall: 0.2707
#
# Epoch Testing Accuracy : 72.2000
# Test AUC-ROC: 0.7743, Test F1 Score: 0.6542, Test Precision: 0.8403, Test Recall: 0.5356
#
# Epoch 57/100, Epoch Accuracy: 67.1750
# Train AUC-ROC: 0.7329, Train F1 Score: 0.5603 , Train Precision: 0.8536, Train Recall: 0.4170
#
# Epoch Testing Accuracy : 71.0000
# Test AUC-ROC: 0.7700, Test F1 Score: 0.6070, Test Precision: 0.9069, Test Recall: 0.4562
#
# Epoch 58/100, Epoch Accuracy: 70.6250
# Train AUC-ROC: 0.7684, Train F1 Score: 0.6453 , Train Precision: 0.8179, Train Recall: 0.5329
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.5310, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 59/100, Epoch Accuracy: 72.7875
# Train AUC-ROC: 0.7712, Train F1 Score: 0.7294 , Train Precision: 0.7275, Train Recall: 0.7313
#
# Epoch Testing Accuracy : 70.3000
# Test AUC-ROC: 0.7161, Test F1 Score: 0.5881, Test Precision: 0.9217, Test Recall: 0.4318
#
# Epoch 60/100, Epoch Accuracy: 65.3125
# Train AUC-ROC: 0.7398, Train F1 Score: 0.6140 , Train Precision: 0.6947, Train Recall: 0.5501
#
# Epoch Testing Accuracy : 77.1000
# Test AUC-ROC: 0.7986, Test F1 Score: 0.7928, Test Precision: 0.7134, Test Recall: 0.8921
#
# Epoch 61/100, Epoch Accuracy: 66.9000
# Train AUC-ROC: 0.7655, Train F1 Score: 0.6140 , Train Precision: 0.7395, Train Recall: 0.5249
#
# Epoch Testing Accuracy : 73.2000
# Test AUC-ROC: 0.7353, Test F1 Score: 0.7702, Test Precision: 0.6652, Test Recall: 0.9145
#
# Epoch 62/100, Epoch Accuracy: 62.5875
# Train AUC-ROC: 0.7271, Train F1 Score: 0.5580 , Train Precision: 0.6847, Train Recall: 0.4708
#
# Epoch Testing Accuracy : 77.5000
# Test AUC-ROC: 0.8717, Test F1 Score: 0.7387, Test Precision: 0.8595, Test Recall: 0.6477
#
# Epoch 63/100, Epoch Accuracy: 69.9000
# Train AUC-ROC: 0.7888, Train F1 Score: 0.6675 , Train Precision: 0.7483, Train Recall: 0.6024
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.7307, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 64/100, Epoch Accuracy: 65.1375
# Train AUC-ROC: 0.7227, Train F1 Score: 0.5368 , Train Precision: 0.8044, Train Recall: 0.4028
#
# Epoch Testing Accuracy : 62.4000
# Test AUC-ROC: 0.6924, Test F1 Score: 0.4198, Test Precision: 0.8662, Test Recall: 0.2770
#
# Epoch 65/100, Epoch Accuracy: 55.5125
# Train AUC-ROC: 0.6325, Train F1 Score: 0.2503 , Train Precision: 0.8082, Train Recall: 0.1481
#
# Epoch Testing Accuracy : 76.2000
# Test AUC-ROC: 0.8448, Test F1 Score: 0.7200, Test Precision: 0.8524, Test Recall: 0.6232
#
# Epoch 66/100, Epoch Accuracy: 74.2250
# Train AUC-ROC: 0.7926, Train F1 Score: 0.7420 , Train Precision: 0.7450, Train Recall: 0.7390
#
# Epoch Testing Accuracy : 79.8000
# Test AUC-ROC: 0.8294, Test F1 Score: 0.8065, Test Precision: 0.7613, Test Recall: 0.8574
#
# Epoch 67/100, Epoch Accuracy: 67.2875
# Train AUC-ROC: 0.7538, Train F1 Score: 0.6529 , Train Precision: 0.6978, Train Recall: 0.6134
#
# Epoch Testing Accuracy : 63.4000
# Test AUC-ROC: 0.7189, Test F1 Score: 0.5969, Test Precision: 0.6499, Test Recall: 0.5519
#
# Epoch 68/100, Epoch Accuracy: 67.7750
# Train AUC-ROC: 0.7575, Train F1 Score: 0.6574 , Train Precision: 0.7042, Train Recall: 0.6164
#
# Epoch Testing Accuracy : 77.8000
# Test AUC-ROC: 0.8433, Test F1 Score: 0.7971, Test Precision: 0.7231, Test Recall: 0.8880
#
# Epoch 69/100, Epoch Accuracy: 66.0375
# Train AUC-ROC: 0.7375, Train F1 Score: 0.5496 , Train Precision: 0.8204, Train Recall: 0.4133
#
# Epoch Testing Accuracy : 81.0000
# Test AUC-ROC: 0.8529, Test F1 Score: 0.7996, Test Precision: 0.8293, Test Recall: 0.7719
#
# Epoch 70/100, Epoch Accuracy: 74.0875
# Train AUC-ROC: 0.8033, Train F1 Score: 0.7281 , Train Precision: 0.7683, Train Recall: 0.6919
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.7270, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 71/100, Epoch Accuracy: 69.3250
# Train AUC-ROC: 0.7577, Train F1 Score: 0.6660 , Train Precision: 0.7335, Train Recall: 0.6099
#
# Epoch Testing Accuracy : 73.7000
# Test AUC-ROC: 0.7830, Test F1 Score: 0.7258, Test Precision: 0.7436, Test Recall: 0.7088
#
# Epoch 72/100, Epoch Accuracy: 72.5125
# Train AUC-ROC: 0.7804, Train F1 Score: 0.6908 , Train Precision: 0.7925, Train Recall: 0.6122
#
# Epoch Testing Accuracy : 77.6000
# Test AUC-ROC: 0.8559, Test F1 Score: 0.7327, Test Precision: 0.8847, Test Recall: 0.6253
#
# Epoch 73/100, Epoch Accuracy: 72.4750
# Train AUC-ROC: 0.8093, Train F1 Score: 0.6881 , Train Precision: 0.7969, Train Recall: 0.6054
#
# Epoch Testing Accuracy : 61.0000
# Test AUC-ROC: 0.6752, Test F1 Score: 0.3412, Test Precision: 1.0000, Test Recall: 0.2057
#
# Epoch 74/100, Epoch Accuracy: 61.1000
# Train AUC-ROC: 0.7156, Train F1 Score: 0.4139 , Train Precision: 0.8467, Train Recall: 0.2739
#
# Epoch Testing Accuracy : 78.7000
# Test AUC-ROC: 0.9043, Test F1 Score: 0.7280, Test Precision: 0.9760, Test Recall: 0.5804
#
# Epoch 75/100, Epoch Accuracy: 83.6375
# Train AUC-ROC: 0.9151, Train F1 Score: 0.8207 , Train Precision: 0.9112, Train Recall: 0.7465
#
# Epoch Testing Accuracy : 79.5000
# Test AUC-ROC: 0.8865, Test F1 Score: 0.7389, Test Precision: 0.9864, Test Recall: 0.5906
#
# Epoch 76/100, Epoch Accuracy: 85.6250
# Train AUC-ROC: 0.9291, Train F1 Score: 0.8459 , Train Precision: 0.9148, Train Recall: 0.7866
#
# Epoch Testing Accuracy : 88.4000
# Test AUC-ROC: 0.9552, Test F1 Score: 0.8797, Test Precision: 0.8964, Test Recall: 0.8635
#
# Epoch 77/100, Epoch Accuracy: 85.1875
# Train AUC-ROC: 0.9260, Train F1 Score: 0.8436 , Train Precision: 0.8963, Train Recall: 0.7969
#
# Epoch Testing Accuracy : 89.0000
# Saved model with Test Model with accuracy 89.00% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_89.000.pth
# Test AUC-ROC: 0.9558, Test F1 Score: 0.8815, Test Precision: 0.9359, Test Recall: 0.8330
#
# Epoch 78/100, Epoch Accuracy: 83.9000
# Train AUC-ROC: 0.9096, Train F1 Score: 0.8324 , Train Precision: 0.8709, Train Recall: 0.7971
#
# Epoch Testing Accuracy : 86.8000
# Test AUC-ROC: 0.9394, Test F1 Score: 0.8590, Test Precision: 0.9034, Test Recall: 0.8187
#
# Epoch 79/100, Epoch Accuracy: 82.0250
# Train AUC-ROC: 0.8965, Train F1 Score: 0.8060 , Train Precision: 0.8783, Train Recall: 0.7448
#
# Epoch Testing Accuracy : 81.7000
# Test AUC-ROC: 0.9006, Test F1 Score: 0.8063, Test Precision: 0.8392, Test Recall: 0.7760
#
# Epoch 80/100, Epoch Accuracy: 82.2500
# Train AUC-ROC: 0.8741, Train F1 Score: 0.8179 , Train Precision: 0.8421, Train Recall: 0.7951
#
# Epoch Testing Accuracy : 81.5000
# Test AUC-ROC: 0.8748, Test F1 Score: 0.8091, Test Precision: 0.8201, Test Recall: 0.7984
#
# Epoch 81/100, Epoch Accuracy: 72.7500
# Train AUC-ROC: 0.8132, Train F1 Score: 0.6635 , Train Precision: 0.8715, Train Recall: 0.5356
#
# Epoch Testing Accuracy : 57.3000
# Test AUC-ROC: 0.6945, Test F1 Score: 0.2306, Test Precision: 1.0000, Test Recall: 0.1303
#
# Epoch 82/100, Epoch Accuracy: 69.8625
# Train AUC-ROC: 0.7897, Train F1 Score: 0.6070 , Train Precision: 0.8771, Train Recall: 0.4641
#
# Epoch Testing Accuracy : 84.0000
# Test AUC-ROC: 0.9341, Test F1 Score: 0.8086, Test Precision: 0.9797, Test Recall: 0.6884
#
# Epoch 83/100, Epoch Accuracy: 83.5500
# Train AUC-ROC: 0.9126, Train F1 Score: 0.8256 , Train Precision: 0.8812, Train Recall: 0.7767
#
# Epoch Testing Accuracy : 80.8000
# Test AUC-ROC: 0.9187, Test F1 Score: 0.7725, Test Precision: 0.9235, Test Recall: 0.6640
#
# Epoch 84/100, Epoch Accuracy: 79.4000
# Train AUC-ROC: 0.8872, Train F1 Score: 0.7693 , Train Precision: 0.8776, Train Recall: 0.6847
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.8662, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 85/100, Epoch Accuracy: 59.7875
# Train AUC-ROC: 0.7171, Train F1 Score: 0.4603 , Train Precision: 0.7040, Train Recall: 0.3420
#
# Epoch Testing Accuracy : 50.9000
# Test AUC-ROC: 0.5938, Test F1 Score: 0.0000, Test Precision: 0.0000, Test Recall: 0.0000
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 86/100, Epoch Accuracy: 74.4625
# Train AUC-ROC: 0.8439, Train F1 Score: 0.7167 , Train Precision: 0.8078, Train Recall: 0.6441
#
# Epoch Testing Accuracy : 81.0000
# Test AUC-ROC: 0.8784, Test F1 Score: 0.8013, Test Precision: 0.8237, Test Recall: 0.7800
#
# Epoch 87/100, Epoch Accuracy: 78.0750
# Train AUC-ROC: 0.8802, Train F1 Score: 0.7591 , Train Precision: 0.8453, Train Recall: 0.6889
#
# Epoch Testing Accuracy : 85.4000
# Test AUC-ROC: 0.9237, Test F1 Score: 0.8423, Test Precision: 0.8966, Test Recall: 0.7943
#
# Epoch 88/100, Epoch Accuracy: 79.5500
# Train AUC-ROC: 0.8601, Train F1 Score: 0.7947 , Train Precision: 0.8002, Train Recall: 0.7894
#
# Epoch Testing Accuracy : 74.1000
# Test AUC-ROC: 0.8961, Test F1 Score: 0.6418, Test Precision: 1.0000, Test Recall: 0.4725
#
# Epoch 89/100, Epoch Accuracy: 87.7375
# Train AUC-ROC: 0.9323, Train F1 Score: 0.8688 , Train Precision: 0.9374, Train Recall: 0.8096
#
# Epoch Testing Accuracy : 89.6000
# Saved model with Test Model with accuracy 89.60% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_89.600.pth
# Test AUC-ROC: 0.9528, Test F1 Score: 0.8887, Test Precision: 0.9368, Test Recall: 0.8452
#
# Epoch 90/100, Epoch Accuracy: 87.1125
# Train AUC-ROC: 0.9372, Train F1 Score: 0.8621 , Train Precision: 0.9299, Train Recall: 0.8036
#
# Epoch Testing Accuracy : 88.2000
# Test AUC-ROC: 0.9554, Test F1 Score: 0.8683, Test Precision: 0.9605, Test Recall: 0.7923
#
# Epoch 91/100, Epoch Accuracy: 86.6375
# Train AUC-ROC: 0.9386, Train F1 Score: 0.8561 , Train Precision: 0.9306, Train Recall: 0.7926
#
# Epoch Testing Accuracy : 89.1000
# Test AUC-ROC: 0.9594, Test F1 Score: 0.8824, Test Precision: 0.9381, Test Recall: 0.8330
#
# Epoch 92/100, Epoch Accuracy: 88.3000
# Train AUC-ROC: 0.9472, Train F1 Score: 0.8772 , Train Precision: 0.9258, Train Recall: 0.8335
#
# Epoch Testing Accuracy : 84.1000
# Test AUC-ROC: 0.9606, Test F1 Score: 0.8096, Test Precision: 0.9826, Test Recall: 0.6884
#
# Epoch 93/100, Epoch Accuracy: 88.0375
# Train AUC-ROC: 0.9490, Train F1 Score: 0.8738 , Train Precision: 0.9278, Train Recall: 0.8258
#
# Epoch Testing Accuracy : 86.8000
# Test AUC-ROC: 0.9604, Test F1 Score: 0.8503, Test Precision: 0.9591, Test Recall: 0.7637
#
# Epoch 94/100, Epoch Accuracy: 89.0625
# Saved model with accuracy train model with accuracy89.06% to saved_models\logp_2024-05-01_23-53-46/TE\train_best_model_89.062.pth
# Train AUC-ROC: 0.9580, Train F1 Score: 0.8850 , Train Precision: 0.9363, Train Recall: 0.8390
#
# Epoch Testing Accuracy : 84.4000
# Test AUC-ROC: 0.9524, Test F1 Score: 0.8165, Test Precision: 0.9666, Test Recall: 0.7067
#
# Epoch 95/100, Epoch Accuracy: 84.8500
# Train AUC-ROC: 0.9162, Train F1 Score: 0.8387 , Train Precision: 0.9000, Train Recall: 0.7851
#
# Epoch Testing Accuracy : 83.8000
# Test AUC-ROC: 0.9602, Test F1 Score: 0.8039, Test Precision: 0.9910, Test Recall: 0.6762
#
# Epoch 96/100, Epoch Accuracy: 86.9000
# Train AUC-ROC: 0.9388, Train F1 Score: 0.8608 , Train Precision: 0.9213, Train Recall: 0.8078
#
# Epoch Testing Accuracy : 85.1000
# Test AUC-ROC: 0.9506, Test F1 Score: 0.8273, Test Precision: 0.9597, Test Recall: 0.7271
#
# Epoch 97/100, Epoch Accuracy: 82.8875
# Train AUC-ROC: 0.9044, Train F1 Score: 0.8081 , Train Precision: 0.9232, Train Recall: 0.7186
#
# Epoch Testing Accuracy : 85.3000
# Test AUC-ROC: 0.9349, Test F1 Score: 0.8435, Test Precision: 0.8839, Test Recall: 0.8065
#
# Epoch 98/100, Epoch Accuracy: 83.2750
# Train AUC-ROC: 0.9068, Train F1 Score: 0.8147 , Train Precision: 0.9168, Train Recall: 0.7331
#
# Epoch Testing Accuracy : 89.9000
# Saved model with Test Model with accuracy 89.90% to saved_models\logp_2024-05-01_23-53-46/TE\test_best_model_89.900.pth
# Test AUC-ROC: 0.9534, Test F1 Score: 0.8910, Test Precision: 0.9472, Test Recall: 0.8411
#
# Epoch 99/100, Epoch Accuracy: 87.8375
# Train AUC-ROC: 0.9445, Train F1 Score: 0.8712 , Train Precision: 0.9289, Train Recall: 0.8203
#
# Epoch Testing Accuracy : 84.6000
# Test AUC-ROC: 0.9566, Test F1 Score: 0.8175, Test Precision: 0.9773, Test Recall: 0.7026
#
# Epoch 100/100, Epoch Accuracy: 87.6750
# Train AUC-ROC: 0.9451, Train F1 Score: 0.8674 , Train Precision: 0.9416, Train Recall: 0.8041
#
# Epoch Testing Accuracy : 84.7000
# Test AUC-ROC: 0.9378, Test F1 Score: 0.8223, Test Precision: 0.9568, Test Recall: 0.7210

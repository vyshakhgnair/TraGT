# %%
import torch
from datetime import datetime
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
import torch
import numpy as np
from rdkit.Chem import AllChem
from rdkit import Chem
from collections import defaultdict
import os,time
from torch_geometric.data import Data
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score

# %%
def load_data_long(dataset, device):
    mole_dict = {1: "H", 2: "He", 3: "Li", 4: "Be", 5: "B", 6: "C", 7: "N", 8: "O", 9: "F", 10: " Ne",
                11: "Na", 12:"Mg", 13: "Al", 14:"Si", 15:"P", 16: "S", 17: "Cl", 18:"Ar", 19:"K", 20:"Ca", 22:"Ti", 24:"Cr", 26:"Fe", 28:"Ni",
                29:"Cu", 31:"Ga", 32:"Ge", 34:"Se", 35:"Br", 40:"Zr", 44:"Ru", 45:"Rh", 46:"Pd", 47:"Ag", 50:"Sn", 51:"Sb", 52:"Te", 53: "I", 65:"Tb", 75:"Re", 77:"Ir", 78:"Pt", 79:"Au", 80:"Hg",
                81:"Tl", 82:"Pb", 83:"Bi"}

    pair_list = ["Br", "Cl", "Si", "Na", "Ca", "Ge", "Cu", "Au", "Sn", "Tb", "Pt", "Re", "Ru", "Bi", "Li", "Fe", "Sb", "Hg","Pb", "Se", "Ag","Cr","Pd","Ga","Mg","Ni","Ir","Rh","Te","Ti","Al","Zr","Tl"]

    data_file = f"./original_datasets/{dataset}/{dataset}_train"
    file = open(data_file, "r")
    node_types = set()
    label_types = set()
    tr_len = 0
    for line in file:
        tr_len += 1
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        i = 0
        s = []
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                s.append(smiles[i] + smiles[i+1])
                i += 2
            else:
                s.append(smiles[i].upper())
                i += 1
        node_types |= set(s)
        label_types.add(label)
    file.close()

    te_len = 0
    data_file = f"./original_datasets/{dataset}/{dataset}_test"
    file = open(data_file, "r")
    for line in file:
        te_len += 1
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        i = 0
        s = []
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                s.append(smiles[i] + smiles[i+1])
                i += 2
            else:
                s.append(smiles[i].upper())
                i += 1
        node_types |= set(s)
        label_types.add(label)
    file.close()

    #print(tr_len)
    #print(te_len)

    node2index = {n: i for i, n in enumerate(node_types)}
    label2index = {l: i for i, l in enumerate(label_types)}

    #print(node2index)
    #print(label2index)

    data_file = f"./original_datasets/{dataset}/{dataset}_train"
    file = open(data_file, "r")
    train_adjlists = []
    train_features = []
    train_sequence = []
    train_labels = torch.zeros(tr_len)
    for line in file:
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        mol = AllChem.MolFromSmiles(smiles)
        graph_nodes = []
        for atom in mol.GetAtoms():
            graph_nodes.append(mole_dict[atom.GetAtomicNum()])
        # print(graph_nodes)
        i = 0
        s = 0
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                i += 2
            else:
                i += 1
            s += 1

        feature = torch.zeros(s, len(node_types))

        map = {}
        se_num = 0
        gr_num = 0
        i = 0
        smiles_seq = []
        while i < len(smiles):
            this_str = smiles[i]
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                this_str = smiles[i] + smiles[i+1]
                i += 2
            else:
                this_str = this_str.upper()
                i += 1
            smiles_seq.append(node2index[this_str])
            if this_str in graph_nodes and this_str == mole_dict[mol.GetAtoms()[gr_num].GetAtomicNum()]:
                map[gr_num] = se_num
                gr_num += 1
            feature[se_num, node2index[this_str]] = 1
            se_num += 1

        adj_list = defaultdict(list)
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            # print(i,j)
            typ = bond.GetBondType()
            adj_list[map[i]].append(map[j])
            adj_list[map[j]].append(map[i])
            if typ == Chem.rdchem.BondType.DOUBLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
            elif typ == Chem.rdchem.BondType.TRIPLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])

        # train_labels[len(train_adjlists)]= int(label2index[label])
        train_labels[len(train_adjlists)]= int(label)
        train_adjlists.append(adj_list)
        train_features.append(torch.FloatTensor(feature).to(device))
        train_sequence.append(torch.tensor(smiles_seq))
    file.close()

    data_file = f"./original_datasets/{dataset}/{dataset}_test"
    file = open(data_file, "r")
    test_adjlists = []
    test_features = []
    test_sequence = []
    test_labels = np.zeros(te_len)
    for line in file:
        smiles = line.split("\t")[1]
        # print(smiles)
        label = line.split("\t")[2][:-1]
        mol = AllChem.MolFromSmiles(smiles)
        graph_nodes = []
        for atom in mol.GetAtoms():
            graph_nodes.append(mole_dict[atom.GetAtomicNum()])
        # print(graph_nodes)
        i = 0
        s = 0
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                i += 2
            else:
                i += 1
            s += 1

        feature = torch.zeros(s, len(node_types))

        map = {}
        se_num = 0
        gr_num = 0
        i = 0
        smiles_seq = []
        while i < len(smiles):
            this_str = smiles[i]
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                this_str = smiles[i] + smiles[i+1]
                i += 2
            else:
                this_str = this_str.upper()
                i += 1
            smiles_seq.append(node2index[this_str])
            if this_str in graph_nodes and this_str == mole_dict[mol.GetAtoms()[gr_num].GetAtomicNum()]:
                map[gr_num] = se_num
                gr_num += 1
            feature[se_num, node2index[this_str]] = 1
            se_num += 1

        adj_list = defaultdict(list)
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            # print(i,j)
            typ = bond.GetBondType()
            adj_list[map[i]].append(map[j])
            adj_list[map[j]].append(map[i])
            if typ == Chem.rdchem.BondType.DOUBLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
            elif typ == Chem.rdchem.BondType.TRIPLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])

        # test_labels[len(test_adjlists)] = int(label2index[label])
        test_labels[len(test_adjlists)] = int(label)
        test_adjlists.append(adj_list)
        test_features.append(torch.FloatTensor(feature).to(device))
        test_sequence.append(torch.tensor(smiles_seq))
    file.close()

    train_data = {}
    train_data['adj_lists'] = train_adjlists
    train_data['features'] = train_features
     # Pad train_sequence to length 100
    padded_train_sequence = []
    for seq in train_sequence:
      padded_seq = torch.nn.functional.pad(seq, (0, 100 - len(seq)), 'constant', 0)
      padded_train_sequence.append(padded_seq)
      train_data['sequence'] = padded_train_sequence

    test_data = {}
    test_data['adj_lists'] = test_adjlists
    test_data['features'] = test_features
    padded_test_sequence = []
    for seq in test_sequence:
      padded_seq = torch.nn.functional.pad(seq, (0, 100 - len(seq)), 'constant', 0)
      padded_test_sequence.append(padded_seq)
      test_data['sequence'] = padded_test_sequence

    return train_data, train_labels, test_data, test_labels


class CustomDataset(Dataset):
    def __init__(self, data_list, sequence_list):
        self.data_list = data_list
        self.sequence_list = sequence_list

    def __getitem__(self, index):
        data = self.data_list[index]
        sequence = self.sequence_list[index]
        return data, sequence

    def __len__(self):
        return len(self.data_list)
    

def adj_list_to_adj_matrix(adj_list):
    num_nodes = max(adj_list.keys()) + 1
    adj_matrix = torch.zeros((num_nodes, num_nodes), dtype=torch.float)
    for node, neighbors in adj_list.items():
        for neighbor in neighbors:
            adj_matrix[node][neighbor] = 1.0
            adj_matrix[neighbor][node] = 1.0
    return adj_matrix

# %%
train_data, train_labels, test_data, test_labels=load_data_long("bbbp", device="cuda:0" if torch.cuda.is_available() else "cpu")
device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:05] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:06] WARNING: not removing hydrogen atom without neighbors
# [18:34:07] WARNING: not removing hydrogen atom without neighbors
# [18:34:07] WARNING: not removing hydrogen atom without neighbors
# [18:34:07] WARNING: not removing hydrogen atom without neighbors
# [18:34:07] WARNING: not removing hydrogen atom without neighbors
# [18:34:07] WARNING: not removing hydrogen atom without neighbors
# [18:34:07] WARNING: not removing hydrogen atom without neighbors

# %%
input_dim_train = train_data['features'][0].size(-1)
input_dim_test = test_data['features'][0].size(-1)


adj_matrices_train = [adj_list_to_adj_matrix(adj_list) for adj_list in train_data['adj_lists']]
adj_matrices_test = [adj_list_to_adj_matrix(adj_list) for adj_list in test_data['adj_lists']]



data_list_train = [Data(x=torch.tensor(features, dtype=torch.float),
                              edge_index=torch.nonzero(adj_matrix, as_tuple=False).t().contiguous(),
                              y=torch.tensor(label, dtype=torch.float))
                         for features, adj_matrix, label in zip(train_data['features'], adj_matrices_train, train_labels)]
data_list_test = [Data(x=torch.tensor(features, dtype=torch.float),
                                edge_index=torch.nonzero(adj_matrix, as_tuple=False).t().contiguous(),
                                y=torch.tensor(label, dtype=torch.float))
                            for features, adj_matrix, label in zip(test_data['features'], adj_matrices_test, test_labels)]

train_dataset = CustomDataset(data_list_train, train_data['sequence'])
test_dataset = CustomDataset(data_list_test, test_data['sequence'])
# Out:
# C:\Users\vysha\AppData\Local\Temp\ipykernel_97372\2688029661.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_list_train = [Data(x=torch.tensor(features, dtype=torch.float),
# C:\Users\vysha\AppData\Local\Temp\ipykernel_97372\2688029661.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y=torch.tensor(label, dtype=torch.float))
# C:\Users\vysha\AppData\Local\Temp\ipykernel_97372\2688029661.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_list_test = [Data(x=torch.tensor(features, dtype=torch.float),

# %%
import torch
import torch.nn as nn

class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length=100):
        super(TransformerModel, self).__init__()
        self.device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.transformer_encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward), num_layers=num_encoder_layers)
        self.fc = nn.Linear(d_model, 1)

    def forward(self, x):
        x = self.embedding(x).to(self.device)
        x = torch.transpose(x, 0, 1).to(self.device)
        x = self.transformer_encoder(x).to(self.device)
        x = torch.mean(x, dim=0).to(self.device)
        x = self.fc(x).to(self.device)
        x = x.mean(dim=0, keepdim=True).to(self.device)
        return x

# Define hyperparameters
vocab_size = 100
d_model = 100
nhead = 4
num_encoder_layers = 3
dim_feedforward = 512
max_length = 100
batch_size = 1
num_epochs = 100

# Initialize model, loss, and optimizer
model = TransformerModel(vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
# Out:
# c:\Python312\Lib\site-packages\torch\nn\modules\transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# 4 HEADS 3 LAYERS

# %%
import torch.nn as nn
current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime('%Y-%m-%d_%H-%M-%S')
data_name = "logp"  # Replace with the actual data name
type = "TE"  # Replace with the actual type

session_name = f'{data_name}_{formatted_datetime}/{type}'
folder_path = os.path.join('saved_models', session_name)
os.makedirs(folder_path, exist_ok=True)

output_dir_train = f'output/{data_name}/train/{type}'
os.makedirs(output_dir_train, exist_ok=True)
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name_train = f'{output_dir_train}/train_accuracy_details_{current_time}.txt'

output_dir_test = f'output/{data_name}/test'
os.makedirs(output_dir_test, exist_ok=True)
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name_test = f'{output_dir_test}/test_accuracy_details_{current_time}.txt'

best_train_accuracy = 0.0
best_test_accuracy = 0.0

# Training loop
reconstruction_weight = 0.1  # Weight for the reconstruction loss
with open(file_name_train, 'a') as file_train, open(file_name_test, 'a') as file_test:
    for epoch in range(100):
        total_correct = 0
        total_samples = 0
        true_labels_train = []
        pred_probs_train = []
        losses = 0.0

        for data_batch in train_dataset:
            graph_data_batch = data_batch[0]
            sequence_inputs = data_batch[1].to(device)
            sequence_targets = graph_data_batch.y

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            output= model(sequence_inputs)

            # Compute binary predictions
            binary_predictions = (output >= 0.5).float()

            # Compute batch accuracy
            batch_correct = (binary_predictions == sequence_targets).sum().item()
            total_correct += batch_correct
            total_samples += 1

            output = output.to(device)
            sequence_targets = sequence_targets.to(device)

            true_labels_train.append(sequence_targets.cpu().numpy().reshape(-1))
            pred_probs_train.append(output.detach().cpu().numpy())

            # Cast sequence_inputs to float
            sequence_inputs = sequence_inputs.float()


            # Compute loss
            loss = criterion(output, sequence_targets.view(-1))
            losses += loss.item()

            # Backward pass
            loss.backward()

            # Update weights
            optimizer.step()

        # Compute epoch accuracy
        epoch_train_accuracy = (total_correct / total_samples) * 100
        print(f"Epoch {epoch + 1}/{100}, Epoch Accuracy: {epoch_train_accuracy:.4f}")

        if epoch_train_accuracy >= best_train_accuracy:
            best_train_accuracy = epoch_train_accuracy
            model_path = os.path.join(folder_path, f'train_best_model_{best_train_accuracy:.3f}.pth')
            torch.save(model.state_dict(), model_path)
            print("Saved model with accuracy train model with accuracy{:.2f}% to {}".format(best_train_accuracy,
                                                                                             model_path))

        true_labels_train = np.concatenate(true_labels_train)
        pred_probs_train = np.concatenate(pred_probs_train)

        precision_train = precision_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        recall_train = recall_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        auc_roc_train = roc_auc_score(true_labels_train, pred_probs_train)
        f1_train = f1_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        print(
            f"Train AUC-ROC: {auc_roc_train:.4f}, Train F1 Score: {f1_train:.4f} , Train Precision: {precision_train:.4f}, Train Recall: {recall_train:.4f}\n")
        file_train.write(
            f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {losses:.4f}, Train Accuracy: {epoch_train_accuracy:.4f}, Train AUC-ROC: {auc_roc_train:.4f}, Train F1 Score: {f1_train:.4f} , Train Precision: {precision_train:.4f}, Train Recall: {recall_train:.4f}\n')

        total_correct = 0
        total_samples = 0
        true_labels_test = []
        pred_probs_test = []

        for data_batch in test_dataset:
            graph_data_batch = data_batch[0]
            sequence_inputs = data_batch[1].to(device)                                                      
            sequence_targets = graph_data_batch.y

            output= model(sequence_inputs)
            binary_predictions = (output >= 0.5).float()

            batch_correct = (binary_predictions == sequence_targets).sum().item()
            total_correct += batch_correct
            total_samples += 1

            true_labels_test.append(sequence_targets.cpu().numpy().reshape(-1))
            pred_probs_test.append(output.detach().cpu().numpy())

        epoch_test_accuracy = (total_correct / total_samples) * 100
        print(f"Epoch Testing Accuracy : {epoch_test_accuracy:.4f}")

        if epoch_test_accuracy >= best_test_accuracy:
            best_test_accuracy = epoch_test_accuracy
            model_path = os.path.join(folder_path, f'test_best_model_{best_test_accuracy:.3f}.pth')
            torch.save(model.state_dict(), model_path)
            print("Saved model with Test Model with accuracy {:.2f}% to {}".format(best_test_accuracy, model_path))

        true_labels_test = np.concatenate(true_labels_test)
        pred_probs_test = np.concatenate(pred_probs_test)
        #pred_probs_test.append(output.detach().cpu().numpy().reshape(-1))
        
        #print(true_labels_test, pred_probs_test)
        precision_test = precision_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        recall_test = recall_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        auc_roc_test = roc_auc_score(true_labels_test, pred_probs_test)
        f1_test = f1_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        print(
            f"Test AUC-ROC: {auc_roc_test:.4f}, Test F1 Score: {f1_test:.4f}, Test Precision: {precision_test:.4f}, Test Recall: {recall_test:.4f}\n")
        file_test.write(
            f'Epoch {epoch + 1}/{num_epochs}, Test Accuracy: {epoch_test_accuracy:.4f},Test AUC-ROC: {auc_roc_test:.4f}, Test F1 Score: {f1_test:.4f}, Test Precision: {precision_test:.4f}, Test Recall: {recall_test:.4f} \n')
file_test.close()
file_train.close()
# Out:
# c:\Python312\Lib\site-packages\torch\nn\functional.py:5476: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Epoch 1/100, Epoch Accuracy: 76.6931
# Saved model with accuracy train model with accuracy76.69% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_76.693.pth
# Train AUC-ROC: 0.6923, Train F1 Score: 0.8579 , Train Precision: 0.8091, Train Recall: 0.9129
#
# Epoch Testing Accuracy : 83.9378
# Saved model with Test Model with accuracy 83.94% to saved_models\logp_2024-05-01_18-34-09/TE\test_best_model_83.938.pth
# Test AUC-ROC: 0.7934, Test F1 Score: 0.9040, Test Precision: 0.8295, Test Recall: 0.9932
#
# Epoch 2/100, Epoch Accuracy: 79.3167
# Saved model with accuracy train model with accuracy79.32% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_79.317.pth
# Train AUC-ROC: 0.6781, Train F1 Score: 0.8761 , Train Precision: 0.8139, Train Recall: 0.9485
#
# Epoch Testing Accuracy : 76.1658
# Test AUC-ROC: 0.4293, Test F1 Score: 0.8647, Test Precision: 0.7617, Test Recall: 1.0000
#
# Epoch 3/100, Epoch Accuracy: 74.9847
# Train AUC-ROC: 0.5529, Train F1 Score: 0.8562 , Train Precision: 0.7684, Train Recall: 0.9667
#
# Epoch Testing Accuracy : 84.4560
# Saved model with Test Model with accuracy 84.46% to saved_models\logp_2024-05-01_18-34-09/TE\test_best_model_84.456.pth
# Test AUC-ROC: 0.7817, Test F1 Score: 0.9074, Test Precision: 0.8305, Test Recall: 1.0000
#
# Epoch 4/100, Epoch Accuracy: 82.6724
# Saved model with accuracy train model with accuracy82.67% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_82.672.pth
# Train AUC-ROC: 0.7946, Train F1 Score: 0.8918 , Train Precision: 0.8597, Train Recall: 0.9264
#
# Epoch Testing Accuracy : 83.4197
# Test AUC-ROC: 0.8736, Test F1 Score: 0.9000, Test Precision: 0.8324, Test Recall: 0.9796
#
# Epoch 5/100, Epoch Accuracy: 83.3435
# Saved model with accuracy train model with accuracy83.34% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_83.344.pth
# Train AUC-ROC: 0.7847, Train F1 Score: 0.8979 , Train Precision: 0.8511, Train Recall: 0.9501
#
# Epoch Testing Accuracy : 87.0466
# Saved model with Test Model with accuracy 87.05% to saved_models\logp_2024-05-01_18-34-09/TE\test_best_model_87.047.pth
# Test AUC-ROC: 0.9080, Test F1 Score: 0.9180, Test Precision: 0.8861, Test Recall: 0.9524
#
# Epoch 6/100, Epoch Accuracy: 84.0146
# Saved model with accuracy train model with accuracy84.01% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_84.015.pth
# Train AUC-ROC: 0.8364, Train F1 Score: 0.8997 , Train Precision: 0.8710, Train Recall: 0.9303
#
# Epoch Testing Accuracy : 89.6373
# Saved model with Test Model with accuracy 89.64% to saved_models\logp_2024-05-01_18-34-09/TE\test_best_model_89.637.pth
# Test AUC-ROC: 0.9231, Test F1 Score: 0.9355, Test Precision: 0.8896, Test Recall: 0.9864
#
# Epoch 7/100, Epoch Accuracy: 85.3569
# Saved model with accuracy train model with accuracy85.36% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_85.357.pth
# Train AUC-ROC: 0.8670, Train F1 Score: 0.9069 , Train Precision: 0.8890, Train Recall: 0.9256
#
# Epoch Testing Accuracy : 90.1554
# Saved model with Test Model with accuracy 90.16% to saved_models\logp_2024-05-01_18-34-09/TE\test_best_model_90.155.pth
# Test AUC-ROC: 0.9429, Test F1 Score: 0.9377, Test Precision: 0.9051, Test Recall: 0.9728
#
# Epoch 8/100, Epoch Accuracy: 84.8078
# Train AUC-ROC: 0.8951, Train F1 Score: 0.9028 , Train Precision: 0.8900, Train Recall: 0.9161
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9374, Test F1 Score: 0.9342, Test Precision: 0.9045, Test Recall: 0.9660
#
# Epoch 9/100, Epoch Accuracy: 86.9433
# Saved model with accuracy train model with accuracy86.94% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_86.943.pth
# Train AUC-ROC: 0.9098, Train F1 Score: 0.9165 , Train Precision: 0.9032, Train Recall: 0.9303
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9383, Test F1 Score: 0.9267, Test Precision: 0.9085, Test Recall: 0.9456
#
# Epoch 10/100, Epoch Accuracy: 86.6382
# Train AUC-ROC: 0.9005, Train F1 Score: 0.9146 , Train Precision: 0.9009, Train Recall: 0.9287
#
# Epoch Testing Accuracy : 91.1917
# Saved model with Test Model with accuracy 91.19% to saved_models\logp_2024-05-01_18-34-09/TE\test_best_model_91.192.pth
# Test AUC-ROC: 0.9543, Test F1 Score: 0.9443, Test Precision: 0.9114, Test Recall: 0.9796
#
# Epoch 11/100, Epoch Accuracy: 85.7230
# Train AUC-ROC: 0.8892, Train F1 Score: 0.9095 , Train Precision: 0.8889, Train Recall: 0.9311
#
# Epoch Testing Accuracy : 86.5285
# Test AUC-ROC: 0.9497, Test F1 Score: 0.9177, Test Precision: 0.8580, Test Recall: 0.9864
#
# Epoch 12/100, Epoch Accuracy: 85.9671
# Train AUC-ROC: 0.9134, Train F1 Score: 0.9111 , Train Precision: 0.8898, Train Recall: 0.9335
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9630, Test F1 Score: 0.9416, Test Precision: 0.9006, Test Recall: 0.9864
#
# Epoch 13/100, Epoch Accuracy: 86.8212
# Train AUC-ROC: 0.9186, Train F1 Score: 0.9172 , Train Precision: 0.8892, Train Recall: 0.9470
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9423, Test F1 Score: 0.9408, Test Precision: 0.9108, Test Recall: 0.9728
#
# Epoch 14/100, Epoch Accuracy: 87.1263
# Saved model with accuracy train model with accuracy87.13% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_87.126.pth
# Train AUC-ROC: 0.9252, Train F1 Score: 0.9173 , Train Precision: 0.9084, Train Recall: 0.9264
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9414, Test F1 Score: 0.9412, Test Precision: 0.9057, Test Recall: 0.9796
#
# Epoch 15/100, Epoch Accuracy: 87.6144
# Saved model with accuracy train model with accuracy87.61% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_87.614.pth
# Train AUC-ROC: 0.9300, Train F1 Score: 0.9202 , Train Precision: 0.9141, Train Recall: 0.9264
#
# Epoch Testing Accuracy : 90.1554
# Test AUC-ROC: 0.9425, Test F1 Score: 0.9373, Test Precision: 0.9103, Test Recall: 0.9660
#
# Epoch 16/100, Epoch Accuracy: 87.8585
# Saved model with accuracy train model with accuracy87.86% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_87.858.pth
# Train AUC-ROC: 0.9285, Train F1 Score: 0.9225 , Train Precision: 0.9080, Train Recall: 0.9375
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9391, Test F1 Score: 0.9290, Test Precision: 0.8834, Test Recall: 0.9796
#
# Epoch 17/100, Epoch Accuracy: 87.6144
# Train AUC-ROC: 0.9321, Train F1 Score: 0.9197 , Train Precision: 0.9186, Train Recall: 0.9208
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9398, Test F1 Score: 0.9346, Test Precision: 0.8994, Test Recall: 0.9728
#
# Epoch 18/100, Epoch Accuracy: 88.0415
# Saved model with accuracy train model with accuracy88.04% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_88.041.pth
# Train AUC-ROC: 0.9407, Train F1 Score: 0.9225 , Train Precision: 0.9211, Train Recall: 0.9240
#
# Epoch Testing Accuracy : 88.0829
# Test AUC-ROC: 0.9428, Test F1 Score: 0.9236, Test Precision: 0.9026, Test Recall: 0.9456
#
# Epoch 19/100, Epoch Accuracy: 88.5906
# Saved model with accuracy train model with accuracy88.59% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_88.591.pth
# Train AUC-ROC: 0.9443, Train F1 Score: 0.9258 , Train Precision: 0.9283, Train Recall: 0.9232
#
# Epoch Testing Accuracy : 88.0829
# Test AUC-ROC: 0.9442, Test F1 Score: 0.9236, Test Precision: 0.9026, Test Recall: 0.9456
#
# Epoch 20/100, Epoch Accuracy: 88.5906
# Saved model with accuracy train model with accuracy88.59% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_88.591.pth
# Train AUC-ROC: 0.9360, Train F1 Score: 0.9260 , Train Precision: 0.9256, Train Recall: 0.9264
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9590, Test F1 Score: 0.9290, Test Precision: 0.8834, Test Recall: 0.9796
#
# Epoch 21/100, Epoch Accuracy: 87.3703
# Train AUC-ROC: 0.9363, Train F1 Score: 0.9184 , Train Precision: 0.9144, Train Recall: 0.9224
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9389, Test F1 Score: 0.9324, Test Precision: 0.9262, Test Recall: 0.9388
#
# Epoch 22/100, Epoch Accuracy: 89.2617
# Saved model with accuracy train model with accuracy89.26% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_89.262.pth
# Train AUC-ROC: 0.9466, Train F1 Score: 0.9305 , Train Precision: 0.9276, Train Recall: 0.9335
#
# Epoch Testing Accuracy : 87.5648
# Test AUC-ROC: 0.9401, Test F1 Score: 0.9189, Test Precision: 0.9128, Test Recall: 0.9252
#
# Epoch 23/100, Epoch Accuracy: 89.4448
# Saved model with accuracy train model with accuracy89.44% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_89.445.pth
# Train AUC-ROC: 0.9556, Train F1 Score: 0.9320 , Train Precision: 0.9258, Train Recall: 0.9382
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9500, Test F1 Score: 0.9333, Test Precision: 0.9150, Test Recall: 0.9524
#
# Epoch 24/100, Epoch Accuracy: 89.3228
# Train AUC-ROC: 0.9463, Train F1 Score: 0.9313 , Train Precision: 0.9230, Train Recall: 0.9398
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9540, Test F1 Score: 0.9333, Test Precision: 0.9150, Test Recall: 0.9524
#
# Epoch 25/100, Epoch Accuracy: 90.1769
# Saved model with accuracy train model with accuracy90.18% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_90.177.pth
# Train AUC-ROC: 0.9514, Train F1 Score: 0.9362 , Train Precision: 0.9366, Train Recall: 0.9359
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9530, Test F1 Score: 0.9400, Test Precision: 0.9216, Test Recall: 0.9592
#
# Epoch 26/100, Epoch Accuracy: 89.8719
# Train AUC-ROC: 0.9565, Train F1 Score: 0.9345 , Train Precision: 0.9315, Train Recall: 0.9375
#
# Epoch Testing Accuracy : 91.7098
# Saved model with Test Model with accuracy 91.71% to saved_models\logp_2024-05-01_18-34-09/TE\test_best_model_91.710.pth
# Test AUC-ROC: 0.9519, Test F1 Score: 0.9470, Test Precision: 0.9226, Test Recall: 0.9728
#
# Epoch 27/100, Epoch Accuracy: 90.9091
# Saved model with accuracy train model with accuracy90.91% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_90.909.pth
# Train AUC-ROC: 0.9579, Train F1 Score: 0.9412 , Train Precision: 0.9379, Train Recall: 0.9446
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9371, Test F1 Score: 0.9267, Test Precision: 0.9085, Test Recall: 0.9456
#
# Epoch 28/100, Epoch Accuracy: 90.9091
# Saved model with accuracy train model with accuracy90.91% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_90.909.pth
# Train AUC-ROC: 0.9631, Train F1 Score: 0.9412 , Train Precision: 0.9379, Train Recall: 0.9446
#
# Epoch Testing Accuracy : 89.1192
# Test AUC-ROC: 0.9438, Test F1 Score: 0.9311, Test Precision: 0.8987, Test Recall: 0.9660
#
# Epoch 29/100, Epoch Accuracy: 90.5430
# Train AUC-ROC: 0.9599, Train F1 Score: 0.9388 , Train Precision: 0.9369, Train Recall: 0.9406
#
# Epoch Testing Accuracy : 87.0466
# Test AUC-ROC: 0.9317, Test F1 Score: 0.9196, Test Precision: 0.8720, Test Recall: 0.9728
#
# Epoch 30/100, Epoch Accuracy: 91.0921
# Saved model with accuracy train model with accuracy91.09% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_91.092.pth
# Train AUC-ROC: 0.9631, Train F1 Score: 0.9417 , Train Precision: 0.9493, Train Recall: 0.9343
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9410, Test F1 Score: 0.9333, Test Precision: 0.9150, Test Recall: 0.9524
#
# Epoch 31/100, Epoch Accuracy: 90.2990
# Train AUC-ROC: 0.9625, Train F1 Score: 0.9369 , Train Precision: 0.9395, Train Recall: 0.9343
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9505, Test F1 Score: 0.9342, Test Precision: 0.9045, Test Recall: 0.9660
#
# Epoch 32/100, Epoch Accuracy: 91.8853
# Saved model with accuracy train model with accuracy91.89% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_91.885.pth
# Train AUC-ROC: 0.9691, Train F1 Score: 0.9476 , Train Precision: 0.9428, Train Recall: 0.9525
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9434, Test F1 Score: 0.9286, Test Precision: 0.8882, Test Recall: 0.9728
#
# Epoch 33/100, Epoch Accuracy: 91.8853
# Saved model with accuracy train model with accuracy91.89% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_91.885.pth
# Train AUC-ROC: 0.9679, Train F1 Score: 0.9477 , Train Precision: 0.9421, Train Recall: 0.9533
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9382, Test F1 Score: 0.9408, Test Precision: 0.9108, Test Recall: 0.9728
#
# Epoch 34/100, Epoch Accuracy: 91.5192
# Train AUC-ROC: 0.9648, Train F1 Score: 0.9455 , Train Precision: 0.9370, Train Recall: 0.9541
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9478, Test F1 Score: 0.9355, Test Precision: 0.8896, Test Recall: 0.9864
#
# Epoch 35/100, Epoch Accuracy: 91.8853
# Saved model with accuracy train model with accuracy91.89% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_91.885.pth
# Train AUC-ROC: 0.9626, Train F1 Score: 0.9481 , Train Precision: 0.9339, Train Recall: 0.9628
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9519, Test F1 Score: 0.9355, Test Precision: 0.8896, Test Recall: 0.9864
#
# Epoch 36/100, Epoch Accuracy: 90.2379
# Train AUC-ROC: 0.9557, Train F1 Score: 0.9363 , Train Precision: 0.9416, Train Recall: 0.9311
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9329, Test F1 Score: 0.9351, Test Precision: 0.8944, Test Recall: 0.9796
#
# Epoch 37/100, Epoch Accuracy: 91.7633
# Train AUC-ROC: 0.9677, Train F1 Score: 0.9468 , Train Precision: 0.9427, Train Recall: 0.9509
#
# Epoch Testing Accuracy : 89.1192
# Test AUC-ROC: 0.9403, Test F1 Score: 0.9307, Test Precision: 0.9038, Test Recall: 0.9592
#
# Epoch 38/100, Epoch Accuracy: 92.0073
# Saved model with accuracy train model with accuracy92.01% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_92.007.pth
# Train AUC-ROC: 0.9684, Train F1 Score: 0.9485 , Train Precision: 0.9415, Train Recall: 0.9557
#
# Epoch Testing Accuracy : 88.0829
# Test AUC-ROC: 0.9496, Test F1 Score: 0.9260, Test Precision: 0.8780, Test Recall: 0.9796
#
# Epoch 39/100, Epoch Accuracy: 92.5564
# Saved model with accuracy train model with accuracy92.56% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_92.556.pth
# Train AUC-ROC: 0.9685, Train F1 Score: 0.9522 , Train Precision: 0.9426, Train Recall: 0.9620
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9500, Test F1 Score: 0.9333, Test Precision: 0.9150, Test Recall: 0.9524
#
# Epoch 40/100, Epoch Accuracy: 91.8853
# Train AUC-ROC: 0.9711, Train F1 Score: 0.9469 , Train Precision: 0.9542, Train Recall: 0.9398
#
# Epoch Testing Accuracy : 91.1917
# Test AUC-ROC: 0.9423, Test F1 Score: 0.9435, Test Precision: 0.9221, Test Recall: 0.9660
#
# Epoch 41/100, Epoch Accuracy: 92.1904
# Train AUC-ROC: 0.9657, Train F1 Score: 0.9496 , Train Precision: 0.9444, Train Recall: 0.9549
#
# Epoch Testing Accuracy : 90.1554
# Test AUC-ROC: 0.9465, Test F1 Score: 0.9373, Test Precision: 0.9103, Test Recall: 0.9660
#
# Epoch 42/100, Epoch Accuracy: 91.6412
# Train AUC-ROC: 0.9673, Train F1 Score: 0.9462 , Train Precision: 0.9392, Train Recall: 0.9533
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9468, Test F1 Score: 0.9333, Test Precision: 0.9150, Test Recall: 0.9524
#
# Epoch 43/100, Epoch Accuracy: 92.5564
# Saved model with accuracy train model with accuracy92.56% to saved_models\logp_2024-05-01_18-34-09/TE\train_best_model_92.556.pth
# Train AUC-ROC: 0.9726, Train F1 Score: 0.9522 , Train Precision: 0.9419, Train Recall: 0.9628
#
# Epoch Testing Accuracy : 87.5648
# Test AUC-ROC: 0.9444, Test F1 Score: 0.9184, Test Precision: 0.9184, Test Recall: 0.9184
#
# Epoch 44/100, Epoch Accuracy: 90.9701
# Train AUC-ROC: 0.9593, Train F1 Score: 0.9416 , Train Precision: 0.9379, Train Recall: 0.9454
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9410, Test F1 Score: 0.9338, Test Precision: 0.9097, Test Recall: 0.9592
#
# Epoch 45/100, Epoch Accuracy: 86.0281
# Train AUC-ROC: 0.9309, Train F1 Score: 0.9063 , Train Precision: 0.9374, Train Recall: 0.8773
#
# Epoch Testing Accuracy : 87.5648
# Test AUC-ROC: 0.9349, Test F1 Score: 0.9178, Test Precision: 0.9241, Test Recall: 0.9116
#
# Epoch 46/100, Epoch Accuracy: 87.5534
# Train AUC-ROC: 0.9445, Train F1 Score: 0.9169 , Train Precision: 0.9438, Train Recall: 0.8915
#
# Epoch Testing Accuracy : 86.5285
# Test AUC-ROC: 0.9144, Test F1 Score: 0.9145, Test Precision: 0.8854, Test Recall: 0.9456
#
# Epoch 47/100, Epoch Accuracy: 87.4314
# Train AUC-ROC: 0.9426, Train F1 Score: 0.9164 , Train Precision: 0.9400, Train Recall: 0.8939
#
# Epoch Testing Accuracy : 86.5285
# Test AUC-ROC: 0.9277, Test F1 Score: 0.9122, Test Precision: 0.9060, Test Recall: 0.9184
#
# Epoch 48/100, Epoch Accuracy: 91.5192
# Train AUC-ROC: 0.9631, Train F1 Score: 0.9453 , Train Precision: 0.9404, Train Recall: 0.9501
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9320, Test F1 Score: 0.9286, Test Precision: 0.8882, Test Recall: 0.9728
#
# Epoch 49/100, Epoch Accuracy: 90.9091
# Train AUC-ROC: 0.9585, Train F1 Score: 0.9409 , Train Precision: 0.9428, Train Recall: 0.9390
#
# Epoch Testing Accuracy : 89.1192
# Test AUC-ROC: 0.9400, Test F1 Score: 0.9311, Test Precision: 0.8987, Test Recall: 0.9660
#
# Epoch 50/100, Epoch Accuracy: 84.8688
# Train AUC-ROC: 0.9261, Train F1 Score: 0.8974 , Train Precision: 0.9402, Train Recall: 0.8583
#
# Epoch Testing Accuracy : 82.3834
# Test AUC-ROC: 0.9190, Test F1 Score: 0.8794, Test Precision: 0.9185, Test Recall: 0.8435
#
# Epoch 51/100, Epoch Accuracy: 86.5162
# Train AUC-ROC: 0.9386, Train F1 Score: 0.9082 , Train Precision: 0.9554, Train Recall: 0.8654
#
# Epoch Testing Accuracy : 82.9016
# Test AUC-ROC: 0.8551, Test F1 Score: 0.8889, Test Precision: 0.8800, Test Recall: 0.8980
#
# Epoch 52/100, Epoch Accuracy: 88.1025
# Train AUC-ROC: 0.9260, Train F1 Score: 0.9214 , Train Precision: 0.9384, Train Recall: 0.9050
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9383, Test F1 Score: 0.9392, Test Precision: 0.9329, Test Recall: 0.9456
#
# Epoch 53/100, Epoch Accuracy: 87.7974
# Train AUC-ROC: 0.9416, Train F1 Score: 0.9187 , Train Precision: 0.9440, Train Recall: 0.8947
#
# Epoch Testing Accuracy : 87.5648
# Test AUC-ROC: 0.9371, Test F1 Score: 0.9231, Test Precision: 0.8727, Test Recall: 0.9796
#
# Epoch 54/100, Epoch Accuracy: 88.4686
# Train AUC-ROC: 0.9419, Train F1 Score: 0.9240 , Train Precision: 0.9387, Train Recall: 0.9097
#
# Epoch Testing Accuracy : 90.1554
# Test AUC-ROC: 0.9453, Test F1 Score: 0.9369, Test Precision: 0.9156, Test Recall: 0.9592
#
# Epoch 55/100, Epoch Accuracy: 88.7126
# Train AUC-ROC: 0.9429, Train F1 Score: 0.9254 , Train Precision: 0.9425, Train Recall: 0.9089
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9380, Test F1 Score: 0.9286, Test Precision: 0.8882, Test Recall: 0.9728
#
# Epoch 56/100, Epoch Accuracy: 89.0177
# Train AUC-ROC: 0.9483, Train F1 Score: 0.9275 , Train Precision: 0.9442, Train Recall: 0.9113
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9379, Test F1 Score: 0.9281, Test Precision: 0.8931, Test Recall: 0.9660
#
# Epoch 57/100, Epoch Accuracy: 87.7364
# Train AUC-ROC: 0.9313, Train F1 Score: 0.9198 , Train Precision: 0.9268, Train Recall: 0.9129
#
# Epoch Testing Accuracy : 81.8653
# Test AUC-ROC: 0.9185, Test F1 Score: 0.8797, Test Precision: 0.8889, Test Recall: 0.8707
#
# Epoch 58/100, Epoch Accuracy: 88.5296
# Train AUC-ROC: 0.9290, Train F1 Score: 0.9264 , Train Precision: 0.9157, Train Recall: 0.9375
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9406, Test F1 Score: 0.9351, Test Precision: 0.8944, Test Recall: 0.9796
#
# Epoch 59/100, Epoch Accuracy: 89.9329
# Train AUC-ROC: 0.8979, Train F1 Score: 0.9371 , Train Precision: 0.9031, Train Recall: 0.9739
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9459, Test F1 Score: 0.9281, Test Precision: 0.8931, Test Recall: 0.9660
#
# Epoch 60/100, Epoch Accuracy: 89.9329
# Train AUC-ROC: 0.9126, Train F1 Score: 0.9377 , Train Precision: 0.8967, Train Recall: 0.9826
#
# Epoch Testing Accuracy : 90.1554
# Test AUC-ROC: 0.9444, Test F1 Score: 0.9373, Test Precision: 0.9103, Test Recall: 0.9660
#
# Epoch 61/100, Epoch Accuracy: 89.2007
# Train AUC-ROC: 0.9224, Train F1 Score: 0.9299 , Train Precision: 0.9303, Train Recall: 0.9295
#
# Epoch Testing Accuracy : 90.1554
# Test AUC-ROC: 0.9601, Test F1 Score: 0.9343, Test Precision: 0.9507, Test Recall: 0.9184
#
# Epoch 62/100, Epoch Accuracy: 89.3228
# Train AUC-ROC: 0.9341, Train F1 Score: 0.9301 , Train Precision: 0.9387, Train Recall: 0.9216
#
# Epoch Testing Accuracy : 88.0829
# Test AUC-ROC: 0.9472, Test F1 Score: 0.9226, Test Precision: 0.9133, Test Recall: 0.9320
#
# Epoch 63/100, Epoch Accuracy: 90.9091
# Train AUC-ROC: 0.9435, Train F1 Score: 0.9419 , Train Precision: 0.9285, Train Recall: 0.9557
#
# Epoch Testing Accuracy : 90.1554
# Test AUC-ROC: 0.9510, Test F1 Score: 0.9373, Test Precision: 0.9103, Test Recall: 0.9660
#
# Epoch 64/100, Epoch Accuracy: 90.9701
# Train AUC-ROC: 0.9511, Train F1 Score: 0.9416 , Train Precision: 0.9386, Train Recall: 0.9446
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9524, Test F1 Score: 0.9400, Test Precision: 0.9216, Test Recall: 0.9592
#
# Epoch 65/100, Epoch Accuracy: 90.6040
# Train AUC-ROC: 0.9503, Train F1 Score: 0.9392 , Train Precision: 0.9370, Train Recall: 0.9414
#
# Epoch Testing Accuracy : 89.1192
# Test AUC-ROC: 0.9519, Test F1 Score: 0.9302, Test Precision: 0.9091, Test Recall: 0.9524
#
# Epoch 66/100, Epoch Accuracy: 90.5430
# Train AUC-ROC: 0.9483, Train F1 Score: 0.9390 , Train Precision: 0.9328, Train Recall: 0.9454
#
# Epoch Testing Accuracy : 85.4922
# Test AUC-ROC: 0.9329, Test F1 Score: 0.9048, Test Precision: 0.9048, Test Recall: 0.9048
#
# Epoch 67/100, Epoch Accuracy: 91.3362
# Train AUC-ROC: 0.9528, Train F1 Score: 0.9451 , Train Precision: 0.9230, Train Recall: 0.9683
#
# Epoch Testing Accuracy : 85.4922
# Test AUC-ROC: 0.9385, Test F1 Score: 0.9054, Test Precision: 0.8993, Test Recall: 0.9116
#
# Epoch 68/100, Epoch Accuracy: 90.1159
# Train AUC-ROC: 0.9493, Train F1 Score: 0.9364 , Train Precision: 0.9291, Train Recall: 0.9438
#
# Epoch Testing Accuracy : 87.5648
# Test AUC-ROC: 0.9454, Test F1 Score: 0.9195, Test Precision: 0.9073, Test Recall: 0.9320
#
# Epoch 69/100, Epoch Accuracy: 88.2855
# Train AUC-ROC: 0.9340, Train F1 Score: 0.9241 , Train Precision: 0.9227, Train Recall: 0.9256
#
# Epoch Testing Accuracy : 87.5648
# Test AUC-ROC: 0.9283, Test F1 Score: 0.9200, Test Precision: 0.9020, Test Recall: 0.9388
#
# Epoch 70/100, Epoch Accuracy: 84.0757
# Train AUC-ROC: 0.8672, Train F1 Score: 0.8987 , Train Precision: 0.8813, Train Recall: 0.9169
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9499, Test F1 Score: 0.9346, Test Precision: 0.8994, Test Recall: 0.9728
#
# Epoch 71/100, Epoch Accuracy: 90.5430
# Train AUC-ROC: 0.9294, Train F1 Score: 0.9403 , Train Precision: 0.9153, Train Recall: 0.9667
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9487, Test F1 Score: 0.9338, Test Precision: 0.9097, Test Recall: 0.9592
#
# Epoch 72/100, Epoch Accuracy: 89.8109
# Train AUC-ROC: 0.8910, Train F1 Score: 0.9360 , Train Precision: 0.9065, Train Recall: 0.9675
#
# Epoch Testing Accuracy : 89.1192
# Test AUC-ROC: 0.9295, Test F1 Score: 0.9320, Test Precision: 0.8889, Test Recall: 0.9796
#
# Epoch 73/100, Epoch Accuracy: 89.3838
# Train AUC-ROC: 0.8888, Train F1 Score: 0.9327 , Train Precision: 0.9116, Train Recall: 0.9549
#
# Epoch Testing Accuracy : 90.6736
# Test AUC-ROC: 0.9497, Test F1 Score: 0.9396, Test Precision: 0.9272, Test Recall: 0.9524
#
# Epoch 74/100, Epoch Accuracy: 75.4118
# Train AUC-ROC: 0.5711, Train F1 Score: 0.8566 , Train Precision: 0.7778, Train Recall: 0.9533
#
# Epoch Testing Accuracy : 76.1658
# Test AUC-ROC: 0.4595, Test F1 Score: 0.8647, Test Precision: 0.7617, Test Recall: 1.0000
#
# Epoch 75/100, Epoch Accuracy: 77.4253
# Train AUC-ROC: 0.6509, Train F1 Score: 0.8713 , Train Precision: 0.7768, Train Recall: 0.9921
#
# Epoch Testing Accuracy : 88.6010
# Test AUC-ROC: 0.9478, Test F1 Score: 0.9281, Test Precision: 0.8931, Test Recall: 0.9660
#
# Epoch 76/100, Epoch Accuracy: 87.4314
# Train AUC-ROC: 0.9048, Train F1 Score: 0.9186 , Train Precision: 0.9165, Train Recall: 0.9208
#
# Epoch Testing Accuracy : 89.6373
# Test AUC-ROC: 0.9423, Test F1 Score: 0.9338, Test Precision: 0.9097, Test Recall: 0.9592
#
# Epoch 77/100, Epoch Accuracy: 88.9567
# Train AUC-ROC: 0.9108, Train F1 Score: 0.9301 , Train Precision: 0.9080, Train Recall: 0.9533
#
# Epoch Testing Accuracy : 86.5285
# Test AUC-ROC: 0.9173, Test F1 Score: 0.9150, Test Precision: 0.8805, Test Recall: 0.9524
#
# Epoch 78/100, Epoch Accuracy: 85.7840
# Train AUC-ROC: 0.8839, Train F1 Score: 0.9094 , Train Precision: 0.8931, Train Recall: 0.9264
#
# Epoch Testing Accuracy : 83.9378
# Test AUC-ROC: 0.8916, Test F1 Score: 0.8963, Test Precision: 0.8816, Test Recall: 0.9116
#
# Epoch 79/100, Epoch Accuracy: 87.0043
# Train AUC-ROC: 0.8997, Train F1 Score: 0.9158 , Train Precision: 0.9140, Train Recall: 0.9177
#
# Epoch Testing Accuracy : 84.4560
# Test AUC-ROC: 0.8965, Test F1 Score: 0.8993, Test Precision: 0.8874, Test Recall: 0.9116
#
# Epoch 80/100, Epoch Accuracy: 85.9671
# Train AUC-ROC: 0.8662, Train F1 Score: 0.9129 , Train Precision: 0.8745, Train Recall: 0.9549
#
# Epoch Testing Accuracy : 83.9378
# Test AUC-ROC: 0.8758, Test F1 Score: 0.9022, Test Precision: 0.8412, Test Recall: 0.9728
#
# Epoch 81/100, Epoch Accuracy: 85.9060
# Train AUC-ROC: 0.8679, Train F1 Score: 0.9131 , Train Precision: 0.8696, Train Recall: 0.9612
#
# Epoch Testing Accuracy : 84.9741
# Test AUC-ROC: 0.8839, Test F1 Score: 0.9073, Test Precision: 0.8554, Test Recall: 0.9660
#
# Epoch 82/100, Epoch Accuracy: 84.5027
# Train AUC-ROC: 0.8358, Train F1 Score: 0.9055 , Train Precision: 0.8540, Train Recall: 0.9636
#
# Epoch Testing Accuracy : 80.8290
# Test AUC-ROC: 0.8274, Test F1 Score: 0.8869, Test Precision: 0.8056, Test Recall: 0.9864
#
# Epoch 83/100, Epoch Accuracy: 85.2959
# Train AUC-ROC: 0.8617, Train F1 Score: 0.9104 , Train Precision: 0.8578, Train Recall: 0.9699
#
# Epoch Testing Accuracy : 84.4560
# Test AUC-ROC: 0.9173, Test F1 Score: 0.9051, Test Precision: 0.8462, Test Recall: 0.9728
#
# Epoch 84/100, Epoch Accuracy: 84.9908
# Train AUC-ROC: 0.8392, Train F1 Score: 0.9090 , Train Precision: 0.8534, Train Recall: 0.9723
#
# Epoch Testing Accuracy : 84.9741
# Test AUC-ROC: 0.9015, Test F1 Score: 0.9085, Test Precision: 0.8471, Test Recall: 0.9796
#
# Epoch 85/100, Epoch Accuracy: 79.9878
# Train AUC-ROC: 0.7346, Train F1 Score: 0.8786 , Train Precision: 0.8249, Train Recall: 0.9398
#
# Epoch Testing Accuracy : 85.4922
# Test AUC-ROC: 0.8620, Test F1 Score: 0.9108, Test Precision: 0.8563, Test Recall: 0.9728
#
# Epoch 86/100, Epoch Accuracy: 85.7230
# Train AUC-ROC: 0.8471, Train F1 Score: 0.9126 , Train Precision: 0.8641, Train Recall: 0.9667
#
# Epoch Testing Accuracy : 85.4922
# Test AUC-ROC: 0.8986, Test F1 Score: 0.9091, Test Precision: 0.8696, Test Recall: 0.9524
#
# Epoch 87/100, Epoch Accuracy: 87.7974
# Train AUC-ROC: 0.8791, Train F1 Score: 0.9242 , Train Precision: 0.8860, Train Recall: 0.9660
#
# Epoch Testing Accuracy : 87.5648
# Test AUC-ROC: 0.9117, Test F1 Score: 0.9221, Test Precision: 0.8820, Test Recall: 0.9660
#
# Epoch 88/100, Epoch Accuracy: 85.1129
# Train AUC-ROC: 0.8719, Train F1 Score: 0.9044 , Train Precision: 0.8953, Train Recall: 0.9137
#
# Epoch Testing Accuracy : 83.4197
# Test AUC-ROC: 0.9031, Test F1 Score: 0.8904, Test Precision: 0.8966, Test Recall: 0.8844
#
# Epoch 89/100, Epoch Accuracy: 80.3539
# Train AUC-ROC: 0.8686, Train F1 Score: 0.8654 , Train Precision: 0.9167, Train Recall: 0.8195
#
# Epoch Testing Accuracy : 80.8290
# Test AUC-ROC: 0.8784, Test F1 Score: 0.8674, Test Precision: 0.9167, Test Recall: 0.8231
#
# Epoch 90/100, Epoch Accuracy: 83.6486
# Train AUC-ROC: 0.9020, Train F1 Score: 0.8889 , Train Precision: 0.9330, Train Recall: 0.8488
#
# Epoch Testing Accuracy : 81.8653
# Test AUC-ROC: 0.9108, Test F1 Score: 0.8754, Test Precision: 0.9179, Test Recall: 0.8367
#
# Epoch 91/100, Epoch Accuracy: 83.3435
# Train AUC-ROC: 0.8983, Train F1 Score: 0.8860 , Train Precision: 0.9373, Train Recall: 0.8401
#
# Epoch Testing Accuracy : 86.0104
# Test AUC-ROC: 0.8861, Test F1 Score: 0.9085, Test Precision: 0.9054, Test Recall: 0.9116
#
# Epoch 92/100, Epoch Accuracy: 86.2111
# Train AUC-ROC: 0.9126, Train F1 Score: 0.9102 , Train Precision: 0.9138, Train Recall: 0.9066
#
# Epoch Testing Accuracy : 85.4922
# Test AUC-ROC: 0.9080, Test F1 Score: 0.9041, Test Precision: 0.9103, Test Recall: 0.8980
#
# Epoch 93/100, Epoch Accuracy: 87.4924
# Train AUC-ROC: 0.9133, Train F1 Score: 0.9196 , Train Precision: 0.9107, Train Recall: 0.9287
#
# Epoch Testing Accuracy : 87.0466
# Test AUC-ROC: 0.9099, Test F1 Score: 0.9153, Test Precision: 0.9122, Test Recall: 0.9184
#
# Epoch 94/100, Epoch Accuracy: 84.5027
# Train AUC-ROC: 0.8903, Train F1 Score: 0.8981 , Train Precision: 0.9105, Train Recall: 0.8860
#
# Epoch Testing Accuracy : 84.4560
# Test AUC-ROC: 0.8687, Test F1 Score: 0.8966, Test Precision: 0.9091, Test Recall: 0.8844
#
# Epoch 95/100, Epoch Accuracy: 84.1977
# Train AUC-ROC: 0.8806, Train F1 Score: 0.8950 , Train Precision: 0.9169, Train Recall: 0.8741
#
# Epoch Testing Accuracy : 84.4560
# Test AUC-ROC: 0.8598, Test F1 Score: 0.8966, Test Precision: 0.9091, Test Recall: 0.8844
#
# Epoch 96/100, Epoch Accuracy: 84.2587
# Train AUC-ROC: 0.8036, Train F1 Score: 0.9032 , Train Precision: 0.8582, Train Recall: 0.9533
#
# Epoch Testing Accuracy : 81.3472
# Test AUC-ROC: 0.8304, Test F1 Score: 0.8896, Test Precision: 0.8101, Test Recall: 0.9864
#
# Epoch 97/100, Epoch Accuracy: 86.5162
# Train AUC-ROC: 0.8317, Train F1 Score: 0.9183 , Train Precision: 0.8613, Train Recall: 0.9834
#
# Epoch Testing Accuracy : 86.5285
# Test AUC-ROC: 0.9095, Test F1 Score: 0.9161, Test Precision: 0.8712, Test Recall: 0.9660
#
# Epoch 98/100, Epoch Accuracy: 85.3569
# Train AUC-ROC: 0.7941, Train F1 Score: 0.9116 , Train Precision: 0.8525, Train Recall: 0.9794
#
# Epoch Testing Accuracy : 82.9016
# Test AUC-ROC: 0.8140, Test F1 Score: 0.8978, Test Precision: 0.8239, Test Recall: 0.9864
#
# Epoch 99/100, Epoch Accuracy: 85.9060
# Train AUC-ROC: 0.7787, Train F1 Score: 0.9148 , Train Precision: 0.8564, Train Recall: 0.9818
#
# Epoch Testing Accuracy : 85.4922
# Test AUC-ROC: 0.8134, Test F1 Score: 0.9103, Test Precision: 0.8606, Test Recall: 0.9660
#
# Epoch 100/100, Epoch Accuracy: 84.1367
# Train AUC-ROC: 0.7972, Train F1 Score: 0.9031 , Train Precision: 0.8534, Train Recall: 0.9588
#
# Epoch Testing Accuracy : 83.4197
# Test AUC-ROC: 0.7965, Test F1 Score: 0.9006, Test Precision: 0.8286, Test Recall: 0.9864

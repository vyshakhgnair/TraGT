# %%
import torch
from datetime import datetime
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
import torch
import numpy as np
from rdkit.Chem import AllChem
from rdkit import Chem
from collections import defaultdict
import os,time
from torch_geometric.data import Data
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score

# %%
def load_data_long(dataset, device):
    mole_dict = {1: "H", 2: "He", 3: "Li", 4: "Be", 5: "B", 6: "C", 7: "N", 8: "O", 9: "F", 10: " Ne",
                11: "Na", 12:"Mg", 13: "Al", 14:"Si", 15:"P", 16: "S", 17: "Cl", 18:"Ar", 19:"K", 20:"Ca", 22:"Ti", 24:"Cr", 26:"Fe", 28:"Ni",
                29:"Cu", 31:"Ga", 32:"Ge", 34:"Se", 35:"Br", 40:"Zr", 44:"Ru", 45:"Rh", 46:"Pd", 47:"Ag", 50:"Sn", 51:"Sb", 52:"Te", 53: "I", 65:"Tb", 75:"Re", 77:"Ir", 78:"Pt", 79:"Au", 80:"Hg",
                81:"Tl", 82:"Pb", 83:"Bi"}

    pair_list = ["Br", "Cl", "Si", "Na", "Ca", "Ge", "Cu", "Au", "Sn", "Tb", "Pt", "Re", "Ru", "Bi", "Li", "Fe", "Sb", "Hg","Pb", "Se", "Ag","Cr","Pd","Ga","Mg","Ni","Ir","Rh","Te","Ti","Al","Zr","Tl"]

    data_file = f"./original_datasets/{dataset}/{dataset}_train"
    file = open(data_file, "r")
    node_types = set()
    label_types = set()
    tr_len = 0
    for line in file:
        tr_len += 1
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        i = 0
        s = []
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                s.append(smiles[i] + smiles[i+1])
                i += 2
            else:
                s.append(smiles[i].upper())
                i += 1
        node_types |= set(s)
        label_types.add(label)
    file.close()

    te_len = 0
    data_file = f"./original_datasets/{dataset}/{dataset}_test"
    file = open(data_file, "r")
    for line in file:
        te_len += 1
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        i = 0
        s = []
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                s.append(smiles[i] + smiles[i+1])
                i += 2
            else:
                s.append(smiles[i].upper())
                i += 1
        node_types |= set(s)
        label_types.add(label)
    file.close()

    #print(tr_len)
    #print(te_len)

    node2index = {n: i for i, n in enumerate(node_types)}
    label2index = {l: i for i, l in enumerate(label_types)}

    #print(node2index)
    #print(label2index)

    data_file = f"./original_datasets/{dataset}/{dataset}_train"
    file = open(data_file, "r")
    train_adjlists = []
    train_features = []
    train_sequence = []
    train_labels = torch.zeros(tr_len)
    for line in file:
        smiles = line.split("\t")[1]
        label = line.split("\t")[2][:-1]
        mol = AllChem.MolFromSmiles(smiles)
        graph_nodes = []
        for atom in mol.GetAtoms():
            graph_nodes.append(mole_dict[atom.GetAtomicNum()])
        # print(graph_nodes)
        i = 0
        s = 0
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                i += 2
            else:
                i += 1
            s += 1

        feature = torch.zeros(s, len(node_types))

        map = {}
        se_num = 0
        gr_num = 0
        i = 0
        smiles_seq = []
        while i < len(smiles):
            this_str = smiles[i]
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                this_str = smiles[i] + smiles[i+1]
                i += 2
            else:
                this_str = this_str.upper()
                i += 1
            smiles_seq.append(node2index[this_str])
            if this_str in graph_nodes and this_str == mole_dict[mol.GetAtoms()[gr_num].GetAtomicNum()]:
                map[gr_num] = se_num
                gr_num += 1
            feature[se_num, node2index[this_str]] = 1
            se_num += 1

        adj_list = defaultdict(list)
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            # print(i,j)
            typ = bond.GetBondType()
            adj_list[map[i]].append(map[j])
            adj_list[map[j]].append(map[i])
            if typ == Chem.rdchem.BondType.DOUBLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
            elif typ == Chem.rdchem.BondType.TRIPLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])

        # train_labels[len(train_adjlists)]= int(label2index[label])
        train_labels[len(train_adjlists)]= int(label)
        train_adjlists.append(adj_list)
        train_features.append(torch.FloatTensor(feature).to(device))
        train_sequence.append(torch.tensor(smiles_seq))
    file.close()

    data_file = f"./original_datasets/{dataset}/{dataset}_test"
    file = open(data_file, "r")
    test_adjlists = []
    test_features = []
    test_sequence = []
    test_labels = np.zeros(te_len)
    for line in file:
        smiles = line.split("\t")[1]
        # print(smiles)
        label = line.split("\t")[2][:-1]
        mol = AllChem.MolFromSmiles(smiles)
        graph_nodes = []
        for atom in mol.GetAtoms():
            graph_nodes.append(mole_dict[atom.GetAtomicNum()])
        # print(graph_nodes)
        i = 0
        s = 0
        while i < len(smiles):
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                i += 2
            else:
                i += 1
            s += 1

        feature = torch.zeros(s, len(node_types))

        map = {}
        se_num = 0
        gr_num = 0
        i = 0
        smiles_seq = []
        while i < len(smiles):
            this_str = smiles[i]
            if i < len(smiles)-1 and (smiles[i] + smiles[i+1]) in pair_list:
                this_str = smiles[i] + smiles[i+1]
                i += 2
            else:
                this_str = this_str.upper()
                i += 1
            smiles_seq.append(node2index[this_str])
            if this_str in graph_nodes and this_str == mole_dict[mol.GetAtoms()[gr_num].GetAtomicNum()]:
                map[gr_num] = se_num
                gr_num += 1
            feature[se_num, node2index[this_str]] = 1
            se_num += 1

        adj_list = defaultdict(list)
        for bond in mol.GetBonds():
            i = bond.GetBeginAtomIdx()
            j = bond.GetEndAtomIdx()
            # print(i,j)
            typ = bond.GetBondType()
            adj_list[map[i]].append(map[j])
            adj_list[map[j]].append(map[i])
            if typ == Chem.rdchem.BondType.DOUBLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
            elif typ == Chem.rdchem.BondType.TRIPLE:
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])
                adj_list[map[i]].append(map[j])
                adj_list[map[j]].append(map[i])

        # test_labels[len(test_adjlists)] = int(label2index[label])
        test_labels[len(test_adjlists)] = int(label)
        test_adjlists.append(adj_list)
        test_features.append(torch.FloatTensor(feature).to(device))
        test_sequence.append(torch.tensor(smiles_seq))
    file.close()

    train_data = {}
    train_data['adj_lists'] = train_adjlists
    train_data['features'] = train_features
     # Pad train_sequence to length 100
    padded_train_sequence = []
    for seq in train_sequence:
      padded_seq = torch.nn.functional.pad(seq, (0, 100 - len(seq)), 'constant', 0)
      padded_train_sequence.append(padded_seq)
      train_data['sequence'] = padded_train_sequence

    test_data = {}
    test_data['adj_lists'] = test_adjlists
    test_data['features'] = test_features
    padded_test_sequence = []
    for seq in test_sequence:
      padded_seq = torch.nn.functional.pad(seq, (0, 100 - len(seq)), 'constant', 0)
      padded_test_sequence.append(padded_seq)
      test_data['sequence'] = padded_test_sequence

    return train_data, train_labels, test_data, test_labels


class CustomDataset(Dataset):
    def __init__(self, data_list, sequence_list):
        self.data_list = data_list
        self.sequence_list = sequence_list

    def __getitem__(self, index):
        data = self.data_list[index]
        sequence = self.sequence_list[index]
        return data, sequence

    def __len__(self):
        return len(self.data_list)
    

def adj_list_to_adj_matrix(adj_list):
    num_nodes = max(adj_list.keys()) + 1
    adj_matrix = torch.zeros((num_nodes, num_nodes), dtype=torch.float)
    for node, neighbors in adj_list.items():
        for neighbor in neighbors:
            adj_matrix[node][neighbor] = 1.0
            adj_matrix[neighbor][node] = 1.0
    return adj_matrix

# %%
train_data, train_labels, test_data, test_labels=load_data_long("logp", device="cuda:0" if torch.cuda.is_available() else "cpu")
device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
input_dim_train = train_data['features'][0].size(-1)
input_dim_test = test_data['features'][0].size(-1)


adj_matrices_train = [adj_list_to_adj_matrix(adj_list) for adj_list in train_data['adj_lists']]
adj_matrices_test = [adj_list_to_adj_matrix(adj_list) for adj_list in test_data['adj_lists']]



data_list_train = [Data(x=torch.tensor(features, dtype=torch.float),
                              edge_index=torch.nonzero(adj_matrix, as_tuple=False).t().contiguous(),
                              y=torch.tensor(label, dtype=torch.float))
                         for features, adj_matrix, label in zip(train_data['features'], adj_matrices_train, train_labels)]
data_list_test = [Data(x=torch.tensor(features, dtype=torch.float),
                                edge_index=torch.nonzero(adj_matrix, as_tuple=False).t().contiguous(),
                                y=torch.tensor(label, dtype=torch.float))
                            for features, adj_matrix, label in zip(test_data['features'], adj_matrices_test, test_labels)]

train_dataset = CustomDataset(data_list_train, train_data['sequence'])
test_dataset = CustomDataset(data_list_test, test_data['sequence'])
# Out:
# C:\Users\vysha\AppData\Local\Temp\ipykernel_138736\2688029661.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_list_train = [Data(x=torch.tensor(features, dtype=torch.float),
# C:\Users\vysha\AppData\Local\Temp\ipykernel_138736\2688029661.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y=torch.tensor(label, dtype=torch.float))
# C:\Users\vysha\AppData\Local\Temp\ipykernel_138736\2688029661.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data_list_test = [Data(x=torch.tensor(features, dtype=torch.float),

# %%
import torch
import torch.nn as nn

class TransformerModel(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length=100):
        super(TransformerModel, self).__init__()
        self.device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.transformer_encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward), num_layers=num_encoder_layers)
        self.fc = nn.Linear(d_model, 1)

    def forward(self, x):
        x = self.embedding(x).to(self.device)
        x = torch.transpose(x, 0, 1).to(self.device)
        x = self.transformer_encoder(x).to(self.device)
        x = torch.mean(x, dim=0).to(self.device)
        x = self.fc(x).to(self.device)
        x = x.mean(dim=0, keepdim=True).to(self.device)
        return x

# Define hyperparameters
vocab_size = 100
d_model = 100
nhead = 4
num_encoder_layers = 3
dim_feedforward = 512
max_length = 100
batch_size = 1
num_epochs = 100

# Initialize model, loss, and optimizer
model = TransformerModel(vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 32
#      29 num_epochs = 100
#      31 # Initialize model, loss, and optimizer
# ---> 32 model = TransformerModel(vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length).to(device)
#      33 criterion = nn.BCEWithLogitsLoss()
#      34 optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)
#
# Cell In[5], line 9, in TransformerModel.__init__(self, vocab_size, d_model, nhead, num_encoder_layers, dim_feedforward, max_length)
#       7 self.device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#       8 self.embedding = nn.Embedding(vocab_size, d_model)
# ----> 9 self.transformer_encoder = nn.TransformerEncoder(nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward), num_layers=num_encoder_layers)
#      10 self.fc = nn.Linear(d_model, 1)
#
# File c:\Python312\Lib\site-packages\torch\nn\modules\transformer.py:564, in TransformerEncoderLayer.__init__(self, d_model, nhead, dim_feedforward, dropout, activation, layer_norm_eps, batch_first, norm_first, bias, device, dtype)
#     560 self.self_attn = MultiheadAttention(d_model, nhead, dropout=dropout,
#     561                                     bias=bias, batch_first=batch_first,
#     562                                     **factory_kwargs)
#     563 # Implementation of Feedforward model
# --> 564 self.linear1 = Linear(d_model, dim_feedforward, bias=bias, **factory_kwargs)
#     565 self.dropout = Dropout(dropout)
#     566 self.linear2 = Linear(dim_feedforward, d_model, bias=bias, **factory_kwargs)
#
# File c:\Python312\Lib\site-packages\torch\nn\modules\linear.py:98, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#      96 self.in_features = in_features
#      97 self.out_features = out_features
# ---> 98 self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
#      99 if bias:
#     100     self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:114] data. DefaultCPUAllocator: not enough memory: you tried to allocate 204800 bytes.

# %% [markdown]
# 4 HEADS 3 LAYERS

# %%
import torch.nn as nn
current_datetime = datetime.now()
formatted_datetime = current_datetime.strftime('%Y-%m-%d_%H-%M-%S')
data_name = "logp"  # Replace with the actual data name
type = "TE"  # Replace with the actual type

session_name = f'{data_name}_{formatted_datetime}/{type}'
folder_path = os.path.join('saved_models', session_name)
os.makedirs(folder_path, exist_ok=True)

output_dir_train = f'output/{data_name}/train/{type}'
os.makedirs(output_dir_train, exist_ok=True)
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name_train = f'{output_dir_train}/train_accuracy_details_{current_time}.txt'

output_dir_test = f'output/{data_name}/test'
os.makedirs(output_dir_test, exist_ok=True)
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
file_name_test = f'{output_dir_test}/test_accuracy_details_{current_time}.txt'

best_train_accuracy = 0.0
best_test_accuracy = 0.0

# Training loop
reconstruction_weight = 0.1  # Weight for the reconstruction loss
with open(file_name_train, 'a') as file_train, open(file_name_test, 'a') as file_test:
    for epoch in range(50):
        total_correct = 0
        total_samples = 0
        true_labels_train = []
        pred_probs_train = []
        losses = 0.0

        for data_batch in train_dataset:
            graph_data_batch = data_batch[0]
            sequence_inputs = data_batch[1].to(device)
            sequence_targets = graph_data_batch.y

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            output= model(sequence_inputs)

            # Compute binary predictions
            binary_predictions = (output >= 0.5).float()

            # Compute batch accuracy
            batch_correct = (binary_predictions == sequence_targets).sum().item()
            total_correct += batch_correct
            total_samples += 1

            output = output.to(device)
            sequence_targets = sequence_targets.to(device)

            true_labels_train.append(sequence_targets.cpu().numpy().reshape(-1))
            pred_probs_train.append(output.detach().cpu().numpy())

            # Cast sequence_inputs to float
            sequence_inputs = sequence_inputs.float()


            # Compute loss
            loss = criterion(output, sequence_targets.view(-1))
            losses += loss.item()

            # Backward pass
            loss.backward()

            # Update weights
            optimizer.step()

        # Compute epoch accuracy
        epoch_train_accuracy = (total_correct / total_samples) * 100
        print(f"Epoch {epoch + 1}/{100}, Epoch Accuracy: {epoch_train_accuracy:.4f}")

        if epoch_train_accuracy >= best_train_accuracy:
            best_train_accuracy = epoch_train_accuracy
            model_path = os.path.join(folder_path, f'train_best_model_{best_train_accuracy:.3f}.pth')
            torch.save(model.state_dict(), model_path)
            print("Saved model with accuracy train model with accuracy{:.2f}% to {}".format(best_train_accuracy,
                                                                                             model_path))

        true_labels_train = np.concatenate(true_labels_train)
        pred_probs_train = np.concatenate(pred_probs_train)

        precision_train = precision_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        recall_train = recall_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        auc_roc_train = roc_auc_score(true_labels_train, pred_probs_train)
        f1_train = f1_score(true_labels_train, (pred_probs_train >= 0.5).astype(int))
        print(
            f"Train AUC-ROC: {auc_roc_train:.4f}, Train F1 Score: {f1_train:.4f} , Train Precision: {precision_train:.4f}, Train Recall: {recall_train:.4f}\n")
        file_train.write(
            f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {losses:.4f}, Train Accuracy: {epoch_train_accuracy:.4f}, Train AUC-ROC: {auc_roc_train:.4f}, Train F1 Score: {f1_train:.4f} , Train Precision: {precision_train:.4f}, Train Recall: {recall_train:.4f}\n')

        total_correct = 0
        total_samples = 0
        true_labels_test = []
        pred_probs_test = []

        for data_batch in test_dataset:
            graph_data_batch = data_batch[0]
            sequence_inputs = data_batch[1].to(device)                                                      
            sequence_targets = graph_data_batch.y

            output= model(sequence_inputs)
            binary_predictions = (output >= 0.5).float()

            batch_correct = (binary_predictions == sequence_targets).sum().item()
            total_correct += batch_correct
            total_samples += 1

            true_labels_test.append(sequence_targets.cpu().numpy().reshape(-1))
            pred_probs_test.append(output.detach().cpu().numpy())

        epoch_test_accuracy = (total_correct / total_samples) * 100
        print(f"Epoch Testing Accuracy : {epoch_test_accuracy:.4f}")

        if epoch_test_accuracy >= best_test_accuracy:
            best_test_accuracy = epoch_test_accuracy
            model_path = os.path.join(folder_path, f'test_best_model_{best_test_accuracy:.3f}.pth')
            torch.save(model.state_dict(), model_path)
            print("Saved model with Test Model with accuracy {:.2f}% to {}".format(best_test_accuracy, model_path))

        true_labels_test = np.concatenate(true_labels_test)
        pred_probs_test = np.concatenate(pred_probs_test)
        #pred_probs_test.append(output.detach().cpu().numpy().reshape(-1))
        
        #print(true_labels_test, pred_probs_test)
        precision_test = precision_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        recall_test = recall_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        auc_roc_test = roc_auc_score(true_labels_test, pred_probs_test)
        f1_test = f1_score(true_labels_test, (pred_probs_test >= 0.5).astype(int))
        print(
            f"Test AUC-ROC: {auc_roc_test:.4f}, Test F1 Score: {f1_test:.4f}, Test Precision: {precision_test:.4f}, Test Recall: {recall_test:.4f}\n")
        file_test.write(
            f'Epoch {epoch + 1}/{num_epochs}, Test Accuracy: {epoch_test_accuracy:.4f},Test AUC-ROC: {auc_roc_test:.4f}, Test F1 Score: {f1_test:.4f}, Test Precision: {precision_test:.4f}, Test Recall: {recall_test:.4f} \n')
file_test.close()
file_train.close()
# Out:
# c:\Python312\Lib\site-packages\torch\nn\functional.py:5476: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Epoch 1/100, Epoch Accuracy: 75.2625
# Saved model with accuracy train model with accuracy75.26% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_75.263.pth
# Train AUC-ROC: 0.8311, Train F1 Score: 0.7261 , Train Precision: 0.8164, Train Recall: 0.6538
#
# Epoch Testing Accuracy : 80.6000
# Saved model with Test Model with accuracy 80.60% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_80.600.pth
# Test AUC-ROC: 0.9098, Test F1 Score: 0.7651, Test Precision: 0.9433, Test Recall: 0.6436
#
# Epoch 2/100, Epoch Accuracy: 81.2250
# Saved model with accuracy train model with accuracy81.23% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_81.225.pth
# Train AUC-ROC: 0.8920, Train F1 Score: 0.7964 , Train Precision: 0.8731, Train Recall: 0.7321
#
# Epoch Testing Accuracy : 82.8000
# Saved model with Test Model with accuracy 82.80% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_82.800.pth
# Test AUC-ROC: 0.9129, Test F1 Score: 0.8130, Test Precision: 0.8718, Test Recall: 0.7617
#
# Epoch 3/100, Epoch Accuracy: 83.2000
# Saved model with accuracy train model with accuracy83.20% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_83.200.pth
# Train AUC-ROC: 0.9084, Train F1 Score: 0.8197 , Train Precision: 0.8876, Train Recall: 0.7615
#
# Epoch Testing Accuracy : 82.1000
# Test AUC-ROC: 0.9235, Test F1 Score: 0.7887, Test Precision: 0.9382, Test Recall: 0.6802
#
# Epoch 4/100, Epoch Accuracy: 83.7250
# Saved model with accuracy train model with accuracy83.73% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_83.725.pth
# Train AUC-ROC: 0.9170, Train F1 Score: 0.8239 , Train Precision: 0.9009, Train Recall: 0.7590
#
# Epoch Testing Accuracy : 76.6000
# Test AUC-ROC: 0.8928, Test F1 Score: 0.6945, Test Precision: 0.9673, Test Recall: 0.5418
#
# Epoch 5/100, Epoch Accuracy: 84.9250
# Saved model with accuracy train model with accuracy84.92% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_84.925.pth
# Train AUC-ROC: 0.9277, Train F1 Score: 0.8383 , Train Precision: 0.9071, Train Recall: 0.7792
#
# Epoch Testing Accuracy : 85.1000
# Saved model with Test Model with accuracy 85.10% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_85.100.pth
# Test AUC-ROC: 0.9383, Test F1 Score: 0.8265, Test Precision: 0.9647, Test Recall: 0.7230
#
# Epoch 6/100, Epoch Accuracy: 85.4750
# Saved model with accuracy train model with accuracy85.47% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_85.475.pth
# Train AUC-ROC: 0.9331, Train F1 Score: 0.8442 , Train Precision: 0.9138, Train Recall: 0.7844
#
# Epoch Testing Accuracy : 83.4000
# Test AUC-ROC: 0.9312, Test F1 Score: 0.8074, Test Precision: 0.9380, Test Recall: 0.7088
#
# Epoch 7/100, Epoch Accuracy: 86.1625
# Saved model with accuracy train model with accuracy86.16% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_86.162.pth
# Train AUC-ROC: 0.9371, Train F1 Score: 0.8524 , Train Precision: 0.9165, Train Recall: 0.7966
#
# Epoch Testing Accuracy : 84.7000
# Test AUC-ROC: 0.9374, Test F1 Score: 0.8263, Test Precision: 0.9333, Test Recall: 0.7413
#
# Epoch 8/100, Epoch Accuracy: 86.8750
# Saved model with accuracy train model with accuracy86.88% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_86.875.pth
# Train AUC-ROC: 0.9417, Train F1 Score: 0.8608 , Train Precision: 0.9195, Train Recall: 0.8091
#
# Epoch Testing Accuracy : 84.4000
# Test AUC-ROC: 0.9364, Test F1 Score: 0.8203, Test Precision: 0.9443, Test Recall: 0.7251
#
# Epoch 9/100, Epoch Accuracy: 87.7250
# Saved model with accuracy train model with accuracy87.72% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_87.725.pth
# Train AUC-ROC: 0.9470, Train F1 Score: 0.8701 , Train Precision: 0.9270, Train Recall: 0.8198
#
# Epoch Testing Accuracy : 82.8000
# Test AUC-ROC: 0.9364, Test F1 Score: 0.7923, Test Precision: 0.9733, Test Recall: 0.6680
#
# Epoch 10/100, Epoch Accuracy: 87.7375
# Saved model with accuracy train model with accuracy87.74% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_87.737.pth
# Train AUC-ROC: 0.9503, Train F1 Score: 0.8696 , Train Precision: 0.9314, Train Recall: 0.8156
#
# Epoch Testing Accuracy : 85.4000
# Saved model with Test Model with accuracy 85.40% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_85.400.pth
# Test AUC-ROC: 0.9381, Test F1 Score: 0.8333, Test Precision: 0.9481, Test Recall: 0.7434
#
# Epoch 11/100, Epoch Accuracy: 88.5375
# Saved model with accuracy train model with accuracy88.54% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_88.538.pth
# Train AUC-ROC: 0.9537, Train F1 Score: 0.8791 , Train Precision: 0.9329, Train Recall: 0.8313
#
# Epoch Testing Accuracy : 85.4000
# Saved model with Test Model with accuracy 85.40% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_85.400.pth
# Test AUC-ROC: 0.9285, Test F1 Score: 0.8322, Test Precision: 0.9551, Test Recall: 0.7373
#
# Epoch 12/100, Epoch Accuracy: 88.7500
# Saved model with accuracy train model with accuracy88.75% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_88.750.pth
# Train AUC-ROC: 0.9552, Train F1 Score: 0.8810 , Train Precision: 0.9378, Train Recall: 0.8308
#
# Epoch Testing Accuracy : 82.7000
# Test AUC-ROC: 0.9335, Test F1 Score: 0.7908, Test Precision: 0.9732, Test Recall: 0.6660
#
# Epoch 13/100, Epoch Accuracy: 88.8500
# Saved model with accuracy train model with accuracy88.85% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_88.850.pth
# Train AUC-ROC: 0.9549, Train F1 Score: 0.8821 , Train Precision: 0.9392, Train Recall: 0.8315
#
# Epoch Testing Accuracy : 86.6000
# Saved model with Test Model with accuracy 86.60% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_86.600.pth
# Test AUC-ROC: 0.9397, Test F1 Score: 0.8511, Test Precision: 0.9364, Test Recall: 0.7800
#
# Epoch 14/100, Epoch Accuracy: 89.1000
# Saved model with accuracy train model with accuracy89.10% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_89.100.pth
# Train AUC-ROC: 0.9576, Train F1 Score: 0.8849 , Train Precision: 0.9405, Train Recall: 0.8355
#
# Epoch Testing Accuracy : 85.4000
# Test AUC-ROC: 0.9458, Test F1 Score: 0.8326, Test Precision: 0.9528, Test Recall: 0.7393
#
# Epoch 15/100, Epoch Accuracy: 89.7125
# Saved model with accuracy train model with accuracy89.71% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_89.712.pth
# Train AUC-ROC: 0.9600, Train F1 Score: 0.8919 , Train Precision: 0.9428, Train Recall: 0.8462
#
# Epoch Testing Accuracy : 86.7000
# Saved model with Test Model with accuracy 86.70% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_86.700.pth
# Test AUC-ROC: 0.9373, Test F1 Score: 0.8543, Test Precision: 0.9242, Test Recall: 0.7943
#
# Epoch 16/100, Epoch Accuracy: 89.8500
# Saved model with accuracy train model with accuracy89.85% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_89.850.pth
# Train AUC-ROC: 0.9611, Train F1 Score: 0.8941 , Train Precision: 0.9374, Train Recall: 0.8547
#
# Epoch Testing Accuracy : 83.1000
# Test AUC-ROC: 0.9396, Test F1 Score: 0.7981, Test Precision: 0.9653, Test Recall: 0.6802
#
# Epoch 17/100, Epoch Accuracy: 90.2125
# Saved model with accuracy train model with accuracy90.21% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_90.212.pth
# Train AUC-ROC: 0.9640, Train F1 Score: 0.8973 , Train Precision: 0.9469, Train Recall: 0.8527
#
# Epoch Testing Accuracy : 85.8000
# Test AUC-ROC: 0.9412, Test F1 Score: 0.8394, Test Precision: 0.9440, Test Recall: 0.7556
#
# Epoch 18/100, Epoch Accuracy: 90.4000
# Saved model with accuracy train model with accuracy90.40% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_90.400.pth
# Train AUC-ROC: 0.9616, Train F1 Score: 0.8997 , Train Precision: 0.9449, Train Recall: 0.8587
#
# Epoch Testing Accuracy : 85.5000
# Test AUC-ROC: 0.9444, Test F1 Score: 0.8331, Test Precision: 0.9577, Test Recall: 0.7373
#
# Epoch 19/100, Epoch Accuracy: 90.0500
# Train AUC-ROC: 0.9628, Train F1 Score: 0.8958 , Train Precision: 0.9430, Train Recall: 0.8532
#
# Epoch Testing Accuracy : 85.0000
# Test AUC-ROC: 0.9405, Test F1 Score: 0.8284, Test Precision: 0.9452, Test Recall: 0.7373
#
# Epoch 20/100, Epoch Accuracy: 90.9750
# Saved model with accuracy train model with accuracy90.97% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_90.975.pth
# Train AUC-ROC: 0.9675, Train F1 Score: 0.9061 , Train Precision: 0.9477, Train Recall: 0.8679
#
# Epoch Testing Accuracy : 84.4000
# Test AUC-ROC: 0.9286, Test F1 Score: 0.8190, Test Precision: 0.9515, Test Recall: 0.7189
#
# Epoch 21/100, Epoch Accuracy: 90.2625
# Train AUC-ROC: 0.9661, Train F1 Score: 0.8979 , Train Precision: 0.9469, Train Recall: 0.8537
#
# Epoch Testing Accuracy : 85.0000
# Test AUC-ROC: 0.9321, Test F1 Score: 0.8295, Test Precision: 0.9383, Test Recall: 0.7434
#
# Epoch 22/100, Epoch Accuracy: 90.5000
# Train AUC-ROC: 0.9660, Train F1 Score: 0.9010 , Train Precision: 0.9440, Train Recall: 0.8617
#
# Epoch Testing Accuracy : 86.6000
# Test AUC-ROC: 0.9245, Test F1 Score: 0.8550, Test Precision: 0.9122, Test Recall: 0.8045
#
# Epoch 23/100, Epoch Accuracy: 91.3000
# Saved model with accuracy train model with accuracy91.30% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_91.300.pth
# Train AUC-ROC: 0.9691, Train F1 Score: 0.9094 , Train Precision: 0.9520, Train Recall: 0.8704
#
# Epoch Testing Accuracy : 87.2000
# Saved model with Test Model with accuracy 87.20% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_87.200.pth
# Test AUC-ROC: 0.9350, Test F1 Score: 0.8621, Test Precision: 0.9153, Test Recall: 0.8147
#
# Epoch 24/100, Epoch Accuracy: 91.2125
# Train AUC-ROC: 0.9698, Train F1 Score: 0.9085 , Train Precision: 0.9509, Train Recall: 0.8696
#
# Epoch Testing Accuracy : 84.5000
# Test AUC-ROC: 0.9249, Test F1 Score: 0.8220, Test Precision: 0.9421, Test Recall: 0.7291
#
# Epoch 25/100, Epoch Accuracy: 91.8125
# Saved model with accuracy train model with accuracy91.81% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_91.812.pth
# Train AUC-ROC: 0.9697, Train F1 Score: 0.9146 , Train Precision: 0.9590, Train Recall: 0.8741
#
# Epoch Testing Accuracy : 87.4000
# Saved model with Test Model with accuracy 87.40% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_87.400.pth
# Test AUC-ROC: 0.9369, Test F1 Score: 0.8633, Test Precision: 0.9234, Test Recall: 0.8106
#
# Epoch 26/100, Epoch Accuracy: 91.8625
# Saved model with accuracy train model with accuracy91.86% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_91.862.pth
# Train AUC-ROC: 0.9716, Train F1 Score: 0.9158 , Train Precision: 0.9519, Train Recall: 0.8824
#
# Epoch Testing Accuracy : 85.2000
# Test AUC-ROC: 0.9356, Test F1 Score: 0.8303, Test Precision: 0.9501, Test Recall: 0.7373
#
# Epoch 27/100, Epoch Accuracy: 91.6875
# Train AUC-ROC: 0.9725, Train F1 Score: 0.9138 , Train Precision: 0.9517, Train Recall: 0.8789
#
# Epoch Testing Accuracy : 87.4000
# Saved model with Test Model with accuracy 87.40% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_87.400.pth
# Test AUC-ROC: 0.9362, Test F1 Score: 0.8618, Test Precision: 0.9335, Test Recall: 0.8004
#
# Epoch 28/100, Epoch Accuracy: 91.8750
# Saved model with accuracy train model with accuracy91.88% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_91.875.pth
# Train AUC-ROC: 0.9707, Train F1 Score: 0.9159 , Train Precision: 0.9526, Train Recall: 0.8819
#
# Epoch Testing Accuracy : 81.5000
# Test AUC-ROC: 0.9312, Test F1 Score: 0.7758, Test Precision: 0.9581, Test Recall: 0.6517
#
# Epoch 29/100, Epoch Accuracy: 90.9500
# Train AUC-ROC: 0.9669, Train F1 Score: 0.9057 , Train Precision: 0.9487, Train Recall: 0.8664
#
# Epoch Testing Accuracy : 87.1000
# Test AUC-ROC: 0.9389, Test F1 Score: 0.8638, Test Precision: 0.8969, Test Recall: 0.8330
#
# Epoch 30/100, Epoch Accuracy: 91.4750
# Train AUC-ROC: 0.9699, Train F1 Score: 0.9117 , Train Precision: 0.9481, Train Recall: 0.8781
#
# Epoch Testing Accuracy : 83.4000
# Test AUC-ROC: 0.9244, Test F1 Score: 0.8042, Test Precision: 0.9552, Test Recall: 0.6945
#
# Epoch 31/100, Epoch Accuracy: 91.6750
# Train AUC-ROC: 0.9712, Train F1 Score: 0.9139 , Train Precision: 0.9490, Train Recall: 0.8814
#
# Epoch Testing Accuracy : 86.8000
# Test AUC-ROC: 0.9360, Test F1 Score: 0.8517, Test Precision: 0.9499, Test Recall: 0.7719
#
# Epoch 32/100, Epoch Accuracy: 91.6000
# Train AUC-ROC: 0.9723, Train F1 Score: 0.9127 , Train Precision: 0.9536, Train Recall: 0.8751
#
# Epoch Testing Accuracy : 86.6000
# Test AUC-ROC: 0.9333, Test F1 Score: 0.8524, Test Precision: 0.9281, Test Recall: 0.7882
#
# Epoch 33/100, Epoch Accuracy: 91.8750
# Saved model with accuracy train model with accuracy91.88% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_91.875.pth
# Train AUC-ROC: 0.9716, Train F1 Score: 0.9161 , Train Precision: 0.9497, Train Recall: 0.8848
#
# Epoch Testing Accuracy : 86.6000
# Test AUC-ROC: 0.9365, Test F1 Score: 0.8494, Test Precision: 0.9474, Test Recall: 0.7699
#
# Epoch 34/100, Epoch Accuracy: 92.4875
# Saved model with accuracy train model with accuracy92.49% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_92.487.pth
# Train AUC-ROC: 0.9731, Train F1 Score: 0.9224 , Train Precision: 0.9564, Train Recall: 0.8908
#
# Epoch Testing Accuracy : 86.4000
# Test AUC-ROC: 0.9337, Test F1 Score: 0.8486, Test Precision: 0.9361, Test Recall: 0.7760
#
# Epoch 35/100, Epoch Accuracy: 91.8625
# Train AUC-ROC: 0.9717, Train F1 Score: 0.9154 , Train Precision: 0.9568, Train Recall: 0.8774
#
# Epoch Testing Accuracy : 87.6000
# Saved model with Test Model with accuracy 87.60% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_87.600.pth
# Test AUC-ROC: 0.9393, Test F1 Score: 0.8672, Test Precision: 0.9142, Test Recall: 0.8248
#
# Epoch 36/100, Epoch Accuracy: 91.5500
# Train AUC-ROC: 0.9673, Train F1 Score: 0.9123 , Train Precision: 0.9511, Train Recall: 0.8766
#
# Epoch Testing Accuracy : 87.4000
# Test AUC-ROC: 0.9363, Test F1 Score: 0.8639, Test Precision: 0.9195, Test Recall: 0.8147
#
# Epoch 37/100, Epoch Accuracy: 90.8875
# Train AUC-ROC: 0.9639, Train F1 Score: 0.9046 , Train Precision: 0.9526, Train Recall: 0.8612
#
# Epoch Testing Accuracy : 88.1000
# Saved model with Test Model with accuracy 88.10% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_88.100.pth
# Test AUC-ROC: 0.9352, Test F1 Score: 0.8730, Test Precision: 0.9170, Test Recall: 0.8330
#
# Epoch 38/100, Epoch Accuracy: 90.1250
# Train AUC-ROC: 0.9586, Train F1 Score: 0.8965 , Train Precision: 0.9448, Train Recall: 0.8529
#
# Epoch Testing Accuracy : 86.9000
# Test AUC-ROC: 0.9319, Test F1 Score: 0.8602, Test Precision: 0.9036, Test Recall: 0.8208
#
# Epoch 39/100, Epoch Accuracy: 88.7625
# Train AUC-ROC: 0.9451, Train F1 Score: 0.8828 , Train Precision: 0.9252, Train Recall: 0.8442
#
# Epoch Testing Accuracy : 86.9000
# Test AUC-ROC: 0.9310, Test F1 Score: 0.8620, Test Precision: 0.8930, Test Recall: 0.8330
#
# Epoch 40/100, Epoch Accuracy: 88.3125
# Train AUC-ROC: 0.9495, Train F1 Score: 0.8759 , Train Precision: 0.9369, Train Recall: 0.8223
#
# Epoch Testing Accuracy : 85.4000
# Test AUC-ROC: 0.9225, Test F1 Score: 0.8447, Test Precision: 0.8842, Test Recall: 0.8086
#
# Epoch 41/100, Epoch Accuracy: 89.8750
# Train AUC-ROC: 0.9594, Train F1 Score: 0.8941 , Train Precision: 0.9406, Train Recall: 0.8519
#
# Epoch Testing Accuracy : 86.0000
# Test AUC-ROC: 0.9274, Test F1 Score: 0.8430, Test Precision: 0.9377, Test Recall: 0.7658
#
# Epoch 42/100, Epoch Accuracy: 90.4250
# Train AUC-ROC: 0.9633, Train F1 Score: 0.9011 , Train Precision: 0.9351, Train Recall: 0.8694
#
# Epoch Testing Accuracy : 88.0000
# Test AUC-ROC: 0.9386, Test F1 Score: 0.8696, Test Precision: 0.9324, Test Recall: 0.8147
#
# Epoch 43/100, Epoch Accuracy: 91.4750
# Train AUC-ROC: 0.9683, Train F1 Score: 0.9119 , Train Precision: 0.9466, Train Recall: 0.8796
#
# Epoch Testing Accuracy : 87.6000
# Test AUC-ROC: 0.9356, Test F1 Score: 0.8658, Test Precision: 0.9238, Test Recall: 0.8147
#
# Epoch 44/100, Epoch Accuracy: 90.8500
# Train AUC-ROC: 0.9631, Train F1 Score: 0.9058 , Train Precision: 0.9362, Train Recall: 0.8774
#
# Epoch Testing Accuracy : 87.9000
# Test AUC-ROC: 0.9313, Test F1 Score: 0.8654, Test Precision: 0.9534, Test Recall: 0.7923
#
# Epoch 45/100, Epoch Accuracy: 90.4250
# Train AUC-ROC: 0.9598, Train F1 Score: 0.9001 , Train Precision: 0.9442, Train Recall: 0.8599
#
# Epoch Testing Accuracy : 84.1000
# Test AUC-ROC: 0.9108, Test F1 Score: 0.8262, Test Precision: 0.8915, Test Recall: 0.7699
#
# Epoch 46/100, Epoch Accuracy: 90.9000
# Train AUC-ROC: 0.9660, Train F1 Score: 0.9055 , Train Precision: 0.9445, Train Recall: 0.8696
#
# Epoch Testing Accuracy : 84.7000
# Test AUC-ROC: 0.9411, Test F1 Score: 0.8223, Test Precision: 0.9568, Test Recall: 0.7210
#
# Epoch 47/100, Epoch Accuracy: 91.8125
# Train AUC-ROC: 0.9709, Train F1 Score: 0.9155 , Train Precision: 0.9487, Train Recall: 0.8846
#
# Epoch Testing Accuracy : 86.1000
# Test AUC-ROC: 0.9331, Test F1 Score: 0.8433, Test Precision: 0.9444, Test Recall: 0.7617
#
# Epoch 48/100, Epoch Accuracy: 91.7000
# Train AUC-ROC: 0.9687, Train F1 Score: 0.9138 , Train Precision: 0.9537, Train Recall: 0.8771
#
# Epoch Testing Accuracy : 88.9000
# Saved model with Test Model with accuracy 88.90% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_88.900.pth
# Test AUC-ROC: 0.9449, Test F1 Score: 0.8803, Test Precision: 0.9358, Test Recall: 0.8310
#
# Epoch 49/100, Epoch Accuracy: 91.8375
# Train AUC-ROC: 0.9720, Train F1 Score: 0.9159 , Train Precision: 0.9477, Train Recall: 0.8861
#
# Epoch Testing Accuracy : 88.1000
# Test AUC-ROC: 0.9464, Test F1 Score: 0.8694, Test Precision: 0.9429, Test Recall: 0.8065
#
# Epoch 50/100, Epoch Accuracy: 91.2625
# Train AUC-ROC: 0.9652, Train F1 Score: 0.9099 , Train Precision: 0.9419, Train Recall: 0.8801
#
# Epoch Testing Accuracy : 85.3000
# Test AUC-ROC: 0.9326, Test F1 Score: 0.8346, Test Precision: 0.9322, Test Recall: 0.7556
#
# Epoch 51/100, Epoch Accuracy: 90.5125
# Train AUC-ROC: 0.9592, Train F1 Score: 0.9014 , Train Precision: 0.9416, Train Recall: 0.8644
#
# Epoch Testing Accuracy : 86.6000
# Test AUC-ROC: 0.9318, Test F1 Score: 0.8511, Test Precision: 0.9364, Test Recall: 0.7800
#
# Epoch 52/100, Epoch Accuracy: 90.9625
# Train AUC-ROC: 0.9652, Train F1 Score: 0.9069 , Train Precision: 0.9379, Train Recall: 0.8779
#
# Epoch Testing Accuracy : 86.0000
# Test AUC-ROC: 0.9326, Test F1 Score: 0.8430, Test Precision: 0.9377, Test Recall: 0.7658
#
# Epoch 53/100, Epoch Accuracy: 89.7250
# Train AUC-ROC: 0.9582, Train F1 Score: 0.8916 , Train Precision: 0.9465, Train Recall: 0.8427
#
# Epoch Testing Accuracy : 84.5000
# Test AUC-ROC: 0.9318, Test F1 Score: 0.8187, Test Precision: 0.9615, Test Recall: 0.7128
#
# Epoch 54/100, Epoch Accuracy: 90.8250
# Train AUC-ROC: 0.9649, Train F1 Score: 0.9049 , Train Precision: 0.9425, Train Recall: 0.8701
#
# Epoch Testing Accuracy : 87.2000
# Test AUC-ROC: 0.9305, Test F1 Score: 0.8596, Test Precision: 0.9311, Test Recall: 0.7984
#
# Epoch 55/100, Epoch Accuracy: 91.4625
# Train AUC-ROC: 0.9692, Train F1 Score: 0.9119 , Train Precision: 0.9447, Train Recall: 0.8814
#
# Epoch Testing Accuracy : 88.5000
# Test AUC-ROC: 0.9450, Test F1 Score: 0.8762, Test Precision: 0.9292, Test Recall: 0.8289
#
# Epoch 56/100, Epoch Accuracy: 91.9125
# Train AUC-ROC: 0.9712, Train F1 Score: 0.9165 , Train Precision: 0.9505, Train Recall: 0.8848
#
# Epoch Testing Accuracy : 87.5000
# Test AUC-ROC: 0.9432, Test F1 Score: 0.8613, Test Precision: 0.9463, Test Recall: 0.7902
#
# Epoch 57/100, Epoch Accuracy: 91.3375
# Train AUC-ROC: 0.9687, Train F1 Score: 0.9099 , Train Precision: 0.9506, Train Recall: 0.8726
#
# Epoch Testing Accuracy : 88.2000
# Test AUC-ROC: 0.9439, Test F1 Score: 0.8734, Test Precision: 0.9229, Test Recall: 0.8289
#
# Epoch 58/100, Epoch Accuracy: 90.5625
# Train AUC-ROC: 0.9611, Train F1 Score: 0.9008 , Train Precision: 0.9527, Train Recall: 0.8542
#
# Epoch Testing Accuracy : 86.5000
# Test AUC-ROC: 0.9411, Test F1 Score: 0.8478, Test Precision: 0.9495, Test Recall: 0.7658
#
# Epoch 59/100, Epoch Accuracy: 91.4500
# Train AUC-ROC: 0.9659, Train F1 Score: 0.9114 , Train Precision: 0.9485, Train Recall: 0.8771
#
# Epoch Testing Accuracy : 88.9000
# Saved model with Test Model with accuracy 88.90% to saved_models\logp_2024-05-01_18-57-57/TE\test_best_model_88.900.pth
# Test AUC-ROC: 0.9486, Test F1 Score: 0.8815, Test Precision: 0.9260, Test Recall: 0.8411
#
# Epoch 60/100, Epoch Accuracy: 91.0250
# Train AUC-ROC: 0.9617, Train F1 Score: 0.9063 , Train Precision: 0.9512, Train Recall: 0.8654
#
# Epoch Testing Accuracy : 87.5000
# Test AUC-ROC: 0.9371, Test F1 Score: 0.8634, Test Precision: 0.9316, Test Recall: 0.8045
#
# Epoch 61/100, Epoch Accuracy: 90.1875
# Train AUC-ROC: 0.9597, Train F1 Score: 0.8984 , Train Precision: 0.9343, Train Recall: 0.8652
#
# Epoch Testing Accuracy : 87.8000
# Test AUC-ROC: 0.9483, Test F1 Score: 0.8656, Test Precision: 0.9424, Test Recall: 0.8004
#
# Epoch 62/100, Epoch Accuracy: 90.9375
# Train AUC-ROC: 0.9643, Train F1 Score: 0.9054 , Train Precision: 0.9502, Train Recall: 0.8647
#
# Epoch Testing Accuracy : 87.6000
# Test AUC-ROC: 0.9449, Test F1 Score: 0.8655, Test Precision: 0.9258, Test Recall: 0.8126
#
# Epoch 63/100, Epoch Accuracy: 91.3375
# Train AUC-ROC: 0.9653, Train F1 Score: 0.9107 , Train Precision: 0.9424, Train Recall: 0.8811
#
# Epoch Testing Accuracy : 87.0000
# Test AUC-ROC: 0.9396, Test F1 Score: 0.8536, Test Precision: 0.9547, Test Recall: 0.7719
#
# Epoch 64/100, Epoch Accuracy: 91.7250
# Train AUC-ROC: 0.9707, Train F1 Score: 0.9138 , Train Precision: 0.9569, Train Recall: 0.8744
#
# Epoch Testing Accuracy : 88.0000
# Test AUC-ROC: 0.9437, Test F1 Score: 0.8684, Test Precision: 0.9406, Test Recall: 0.8065
#
# Epoch 65/100, Epoch Accuracy: 92.6000
# Saved model with accuracy train model with accuracy92.60% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_92.600.pth
# Train AUC-ROC: 0.9717, Train F1 Score: 0.9239 , Train Precision: 0.9543, Train Recall: 0.8953
#
# Epoch Testing Accuracy : 87.2000
# Test AUC-ROC: 0.9406, Test F1 Score: 0.8590, Test Precision: 0.9353, Test Recall: 0.7943
#
# Epoch 66/100, Epoch Accuracy: 92.1375
# Train AUC-ROC: 0.9693, Train F1 Score: 0.9190 , Train Precision: 0.9505, Train Recall: 0.8896
#
# Epoch Testing Accuracy : 87.4000
# Test AUC-ROC: 0.9428, Test F1 Score: 0.8642, Test Precision: 0.9176, Test Recall: 0.8167
#
# Epoch 67/100, Epoch Accuracy: 90.3625
# Train AUC-ROC: 0.9610, Train F1 Score: 0.8999 , Train Precision: 0.9393, Train Recall: 0.8637
#
# Epoch Testing Accuracy : 83.4000
# Test AUC-ROC: 0.9258, Test F1 Score: 0.8172, Test Precision: 0.8897, Test Recall: 0.7556
#
# Epoch 68/100, Epoch Accuracy: 88.5500
# Train AUC-ROC: 0.9501, Train F1 Score: 0.8806 , Train Precision: 0.9227, Train Recall: 0.8422
#
# Epoch Testing Accuracy : 85.7000
# Test AUC-ROC: 0.9291, Test F1 Score: 0.8409, Test Precision: 0.9265, Test Recall: 0.7699
#
# Epoch 69/100, Epoch Accuracy: 88.9625
# Train AUC-ROC: 0.9459, Train F1 Score: 0.8842 , Train Precision: 0.9330, Train Recall: 0.8402
#
# Epoch Testing Accuracy : 85.4000
# Test AUC-ROC: 0.9137, Test F1 Score: 0.8423, Test Precision: 0.8966, Test Recall: 0.7943
#
# Epoch 70/100, Epoch Accuracy: 89.5625
# Train AUC-ROC: 0.9529, Train F1 Score: 0.8911 , Train Precision: 0.9344, Train Recall: 0.8517
#
# Epoch Testing Accuracy : 85.9000
# Test AUC-ROC: 0.9286, Test F1 Score: 0.8508, Test Precision: 0.8855, Test Recall: 0.8187
#
# Epoch 71/100, Epoch Accuracy: 88.0500
# Train AUC-ROC: 0.9431, Train F1 Score: 0.8727 , Train Precision: 0.9368, Train Recall: 0.8168
#
# Epoch Testing Accuracy : 87.4000
# Test AUC-ROC: 0.9412, Test F1 Score: 0.8624, Test Precision: 0.9294, Test Recall: 0.8045
#
# Epoch 72/100, Epoch Accuracy: 88.6250
# Train AUC-ROC: 0.9439, Train F1 Score: 0.8805 , Train Precision: 0.9308, Train Recall: 0.8352
#
# Epoch Testing Accuracy : 85.9000
# Test AUC-ROC: 0.9280, Test F1 Score: 0.8462, Test Precision: 0.9108, Test Recall: 0.7902
#
# Epoch 73/100, Epoch Accuracy: 88.2875
# Train AUC-ROC: 0.9501, Train F1 Score: 0.8774 , Train Precision: 0.9234, Train Recall: 0.8357
#
# Epoch Testing Accuracy : 82.2000
# Test AUC-ROC: 0.9298, Test F1 Score: 0.7921, Test Precision: 0.9288, Test Recall: 0.6904
#
# Epoch 74/100, Epoch Accuracy: 88.2375
# Train AUC-ROC: 0.9477, Train F1 Score: 0.8766 , Train Precision: 0.9250, Train Recall: 0.8330
#
# Epoch Testing Accuracy : 83.8000
# Test AUC-ROC: 0.9265, Test F1 Score: 0.8107, Test Precision: 0.9507, Test Recall: 0.7067
#
# Epoch 75/100, Epoch Accuracy: 88.2250
# Train AUC-ROC: 0.9469, Train F1 Score: 0.8760 , Train Precision: 0.9283, Train Recall: 0.8293
#
# Epoch Testing Accuracy : 83.0000
# Test AUC-ROC: 0.9256, Test F1 Score: 0.7962, Test Precision: 0.9679, Test Recall: 0.6762
#
# Epoch 76/100, Epoch Accuracy: 88.6875
# Train AUC-ROC: 0.9506, Train F1 Score: 0.8822 , Train Precision: 0.9230, Train Recall: 0.8450
#
# Epoch Testing Accuracy : 86.1000
# Test AUC-ROC: 0.9323, Test F1 Score: 0.8497, Test Precision: 0.9055, Test Recall: 0.8004
#
# Epoch 77/100, Epoch Accuracy: 89.0250
# Train AUC-ROC: 0.9541, Train F1 Score: 0.8854 , Train Precision: 0.9293, Train Recall: 0.8455
#
# Epoch Testing Accuracy : 86.8000
# Test AUC-ROC: 0.9258, Test F1 Score: 0.8611, Test Precision: 0.8911, Test Recall: 0.8330
#
# Epoch 78/100, Epoch Accuracy: 88.2250
# Train AUC-ROC: 0.9498, Train F1 Score: 0.8758 , Train Precision: 0.9300, Train Recall: 0.8275
#
# Epoch Testing Accuracy : 86.8000
# Test AUC-ROC: 0.9350, Test F1 Score: 0.8587, Test Precision: 0.9052, Test Recall: 0.8167
#
# Epoch 79/100, Epoch Accuracy: 87.8625
# Train AUC-ROC: 0.9473, Train F1 Score: 0.8725 , Train Precision: 0.9222, Train Recall: 0.8278
#
# Epoch Testing Accuracy : 85.8000
# Test AUC-ROC: 0.9307, Test F1 Score: 0.8467, Test Precision: 0.9011, Test Recall: 0.7984
#
# Epoch 80/100, Epoch Accuracy: 89.5250
# Train AUC-ROC: 0.9550, Train F1 Score: 0.8908 , Train Precision: 0.9331, Train Recall: 0.8522
#
# Epoch Testing Accuracy : 86.0000
# Test AUC-ROC: 0.9355, Test F1 Score: 0.8491, Test Precision: 0.9016, Test Recall: 0.8024
#
# Epoch 81/100, Epoch Accuracy: 89.4000
# Train AUC-ROC: 0.9534, Train F1 Score: 0.8898 , Train Precision: 0.9297, Train Recall: 0.8532
#
# Epoch Testing Accuracy : 86.1000
# Test AUC-ROC: 0.9275, Test F1 Score: 0.8450, Test Precision: 0.9335, Test Recall: 0.7719
#
# Epoch 82/100, Epoch Accuracy: 89.7875
# Train AUC-ROC: 0.9556, Train F1 Score: 0.8938 , Train Precision: 0.9342, Train Recall: 0.8567
#
# Epoch Testing Accuracy : 87.0000
# Test AUC-ROC: 0.9388, Test F1 Score: 0.8565, Test Precision: 0.9349, Test Recall: 0.7902
#
# Epoch 83/100, Epoch Accuracy: 90.8375
# Train AUC-ROC: 0.9631, Train F1 Score: 0.9046 , Train Precision: 0.9469, Train Recall: 0.8659
#
# Epoch Testing Accuracy : 87.6000
# Test AUC-ROC: 0.9346, Test F1 Score: 0.8610, Test Precision: 0.9576, Test Recall: 0.7821
#
# Epoch 84/100, Epoch Accuracy: 91.0000
# Train AUC-ROC: 0.9649, Train F1 Score: 0.9063 , Train Precision: 0.9485, Train Recall: 0.8676
#
# Epoch Testing Accuracy : 87.3000
# Test AUC-ROC: 0.9330, Test F1 Score: 0.8597, Test Precision: 0.9396, Test Recall: 0.7923
#
# Epoch 85/100, Epoch Accuracy: 91.3125
# Train AUC-ROC: 0.9642, Train F1 Score: 0.9098 , Train Precision: 0.9486, Train Recall: 0.8741
#
# Epoch Testing Accuracy : 87.6000
# Test AUC-ROC: 0.9381, Test F1 Score: 0.8613, Test Precision: 0.9553, Test Recall: 0.7841
#
# Epoch 86/100, Epoch Accuracy: 91.4000
# Train AUC-ROC: 0.9642, Train F1 Score: 0.9108 , Train Precision: 0.9494, Train Recall: 0.8751
#
# Epoch Testing Accuracy : 87.6000
# Test AUC-ROC: 0.9391, Test F1 Score: 0.8637, Test Precision: 0.9379, Test Recall: 0.8004
#
# Epoch 87/100, Epoch Accuracy: 91.1875
# Train AUC-ROC: 0.9616, Train F1 Score: 0.9086 , Train Precision: 0.9468, Train Recall: 0.8734
#
# Epoch Testing Accuracy : 87.4000
# Test AUC-ROC: 0.9449, Test F1 Score: 0.8642, Test Precision: 0.9176, Test Recall: 0.8167
#
# Epoch 88/100, Epoch Accuracy: 91.6000
# Train AUC-ROC: 0.9649, Train F1 Score: 0.9129 , Train Precision: 0.9514, Train Recall: 0.8774
#
# Epoch Testing Accuracy : 87.9000
# Test AUC-ROC: 0.9406, Test F1 Score: 0.8711, Test Precision: 0.9129, Test Recall: 0.8330
#
# Epoch 89/100, Epoch Accuracy: 91.3875
# Train AUC-ROC: 0.9668, Train F1 Score: 0.9103 , Train Precision: 0.9528, Train Recall: 0.8714
#
# Epoch Testing Accuracy : 88.7000
# Test AUC-ROC: 0.9419, Test F1 Score: 0.8781, Test Precision: 0.9335, Test Recall: 0.8289
#
# Epoch 90/100, Epoch Accuracy: 91.2750
# Train AUC-ROC: 0.9644, Train F1 Score: 0.9095 , Train Precision: 0.9474, Train Recall: 0.8746
#
# Epoch Testing Accuracy : 86.1000
# Test AUC-ROC: 0.9299, Test F1 Score: 0.8461, Test Precision: 0.9272, Test Recall: 0.7780
#
# Epoch 91/100, Epoch Accuracy: 91.2875
# Train AUC-ROC: 0.9642, Train F1 Score: 0.9097 , Train Precision: 0.9471, Train Recall: 0.8751
#
# Epoch Testing Accuracy : 87.3000
# Test AUC-ROC: 0.9390, Test F1 Score: 0.8633, Test Precision: 0.9155, Test Recall: 0.8167
#
# Epoch 92/100, Epoch Accuracy: 91.6250
# Train AUC-ROC: 0.9670, Train F1 Score: 0.9137 , Train Precision: 0.9454, Train Recall: 0.8841
#
# Epoch Testing Accuracy : 88.2000
# Test AUC-ROC: 0.9324, Test F1 Score: 0.8747, Test Precision: 0.9135, Test Recall: 0.8391
#
# Epoch 93/100, Epoch Accuracy: 90.2750
# Train AUC-ROC: 0.9573, Train F1 Score: 0.8986 , Train Precision: 0.9413, Train Recall: 0.8597
#
# Epoch Testing Accuracy : 86.2000
# Test AUC-ROC: 0.9346, Test F1 Score: 0.8538, Test Precision: 0.8896, Test Recall: 0.8208
#
# Epoch 94/100, Epoch Accuracy: 90.9375
# Train AUC-ROC: 0.9614, Train F1 Score: 0.9065 , Train Precision: 0.9393, Train Recall: 0.8759
#
# Epoch Testing Accuracy : 87.6000
# Test AUC-ROC: 0.9328, Test F1 Score: 0.8672, Test Precision: 0.9142, Test Recall: 0.8248
#
# Epoch 95/100, Epoch Accuracy: 91.1750
# Train AUC-ROC: 0.9632, Train F1 Score: 0.9084 , Train Precision: 0.9472, Train Recall: 0.8726
#
# Epoch Testing Accuracy : 86.8000
# Test AUC-ROC: 0.9263, Test F1 Score: 0.8565, Test Precision: 0.9184, Test Recall: 0.8024
#
# Epoch 96/100, Epoch Accuracy: 91.2875
# Train AUC-ROC: 0.9637, Train F1 Score: 0.9105 , Train Precision: 0.9393, Train Recall: 0.8833
#
# Epoch Testing Accuracy : 86.6000
# Test AUC-ROC: 0.9342, Test F1 Score: 0.8553, Test Precision: 0.9103, Test Recall: 0.8065
#
# Epoch 97/100, Epoch Accuracy: 91.9500
# Train AUC-ROC: 0.9677, Train F1 Score: 0.9173 , Train Precision: 0.9462, Train Recall: 0.8901
#
# Epoch Testing Accuracy : 87.5000
# Test AUC-ROC: 0.9248, Test F1 Score: 0.8631, Test Precision: 0.9336, Test Recall: 0.8024
#
# Epoch 98/100, Epoch Accuracy: 92.1625
# Train AUC-ROC: 0.9688, Train F1 Score: 0.9193 , Train Precision: 0.9510, Train Recall: 0.8896
#
# Epoch Testing Accuracy : 87.5000
# Test AUC-ROC: 0.9296, Test F1 Score: 0.8654, Test Precision: 0.9178, Test Recall: 0.8187
#
# Epoch 99/100, Epoch Accuracy: 92.9750
# Saved model with accuracy train model with accuracy92.97% to saved_models\logp_2024-05-01_18-57-57/TE\train_best_model_92.975.pth
# Train AUC-ROC: 0.9720, Train F1 Score: 0.9278 , Train Precision: 0.9573, Train Recall: 0.9000
#
# Epoch Testing Accuracy : 87.2000
# Test AUC-ROC: 0.9330, Test F1 Score: 0.8609, Test Precision: 0.9231, Test Recall: 0.8065
#
# Epoch 100/100, Epoch Accuracy: 92.3875
# Train AUC-ROC: 0.9723, Train F1 Score: 0.9219 , Train Precision: 0.9498, Train Recall: 0.8956
#
# Epoch Testing Accuracy : 87.3000
# Test AUC-ROC: 0.9351, Test F1 Score: 0.8624, Test Precision: 0.9213, Test Recall: 0.8106
